# %% [markdown]
# # Day 57: 2026-09-09## Phase(s)P12: Multimodal AI | P13: Tools & Protocols## Lessons Covered25 Multimodal Agents and Computer-Use (Capstone); 01 The Tool Interface; 02 Function Calling Deep Dive## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/12-multimodal-ai/25-multimodal-agents-computer-use | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/13-tools-and-protocols/01-the-tool-interface/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/13-tools-and-protocols/02-function-calling-deep-dive/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ MCP Server## Project Application TaskBuild/extend an MCP server exposing CartQ vendor/order tools (the flagship MCP portfolio piece) using today's protocol concept.
