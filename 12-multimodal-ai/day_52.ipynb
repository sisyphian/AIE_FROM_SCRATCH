# %% [markdown]
# # Day 52: 2026-09-03## Phase(s)P12: Multimodal AI## Lessons Covered15 Janus-Pro Decoupled Encoders; 16 MIO Any-to-Any Streaming## Est. Study Time (hrs)4## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/12-multimodal-ai/15-janus-pro-decoupled-encoders | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/12-multimodal-ai/16-mio-any-to-any-streaming## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Multimodal Search (stretch)## Project Application TaskOptional stretch: prototype multimodal search/RAG over menu photos for CartQ using today's technique.
