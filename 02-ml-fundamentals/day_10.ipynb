# %% [markdown]
# # Day 10: 2026-07-16## Phase(s)P2: ML Fundamentals## Lessons Covered12 Hyperparameter Tuning & AutoML; 13 ML Pipelines & Experiment Tracking; 14 Naive Bayes — Multinomial, Gaussian, Bernoulli; 15 Time Series Fundamentals; 16 Anomaly Detection## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Prep-Time Model## Project Application TaskApply today's ML concept to the CartQ LightGBM prep-time prediction feature (feature engineering, evaluation, or tuning on synthetic order data).## MilestonePHASE 2 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
