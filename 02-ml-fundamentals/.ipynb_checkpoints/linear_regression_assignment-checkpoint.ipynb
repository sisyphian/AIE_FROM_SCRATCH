# %% [markdown]
# ```
# implement multivariate lineaer regression
# X = [
#     [2, 70, 3],
#     [3, 75, 5],
#     [4, 80, 6],
#     [5, 85, 7],
#     [6, 90, 8],
#     [7, 92, 9],
#     [8, 95, 10],
#     [9, 97, 10],
#     [10, 98, 10],
#     [11, 100, 10],
# ]
#
# y = [
#     40,
#     48,
#     56,
#     64,
#     72,
#     80,
#     88,
#     92,
#     96,
#     100,
# ]
#
# X_test = [
#     [2.5, 72, 4],
#     [3.5, 78, 5],
#     [4.5, 83, 6],
#     [5.5, 87, 7],
#     [6.5, 91, 8],
#     [7.5, 94, 9],
#     [8.5, 96, 10],
#     [9.5, 99, 10],
# ]
#
# # Expected Marks
# y_test = [
#     44,
#     52,
#     60,
#     68,
#     76,
#     84,
#     90,
#     98,
# ]
#
#
# ```

# %%
X = [
    [2, 70, 3],
    [3, 75, 5],
    [4, 80, 6],
    [5, 85, 7],
    [6, 90, 8],
    [7, 92, 9],
    [8, 95, 10],
    [9, 97, 10],
    [10, 98, 10],
    [11, 100, 10],
]

y = [
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    92,
    96,
    100,
]


X_test = [
    [2.5, 72, 4],
    [3.5, 78, 5],
    [4.5, 83, 6],
    [5.5, 87, 7],
    [6.5, 91, 8],
    [7.5, 94, 9],
    [8.5, 96, 10],
    [9.5, 99, 10],
]

# Expected Marks
y_test = [
    44,
    52,
    60,
    68,
    76,
    84,
    90,
    98,
]

# %%
print("Hello World")
# Out:
# Hello World

# %%
X_scaled = []

for row in X:
    X_scaled.append([
        row[0] / 10,
        row[1] / 100,
        row[2] / 10
    ])

X_test_scaled = []

for row in X_test:
    X_test_scaled.append([
        row[0] / 10,
        row[1] / 100,
        row[2] / 10
    ])

# %%
class LinearRegression:
    def __init__(self,n_features=1,learning_rate=0.01):
        self.weights=[0.00]*n_features
        self.bias=0.00
        self.lr=learning_rate
        self.n_features=n_features
        self.cost_history=[]

    def predict_single(self,X):
        # prediction for single feature
        # X -> vector 
        y = 0
        for xi,wi in zip(X,self.weights):
            y+= xi * wi

        y+=self.bias
        return y

    def predict(self,X):
        predicted_arr=[]

        for x in X:
            predicted_arr.append(self.predict_single(x))
        return predicted_arr

    def cost(self,X,y):
        # y is the vector and X is the matrix so have to calculate the mse
        cost=0
        n=len(y)
        y_predicted=self.predict(X)

        for pred,actual in zip(y_predicted,y):
            cost+=(pred-actual)**2

        cost = (1/n)*cost

        return cost 
    def r_squared(self, X, y):
            predictions = self.predict(X)
            y_mean = sum(y) / len(y)
            ss_res = sum((actual - pred) ** 2 for actual, pred in zip(y, predictions))
            ss_tot = sum((actual - y_mean) ** 2 for actual in y)
            return 1 - (ss_res / ss_tot)
            


    def fit(self,X,y,epochs=100,print_at=100):

        n=len(y)
        
        for epoch in range(epochs):
            y_predicted = self.predict(X)
            for j in range(self.n_features):
                # grad_w=(2/n)*sum(pred-actual for pred ,actual in zip(y_predicted,y)
                
                grad_w=0
                
                for pred,actual,i in zip(y_predicted,y,range(n)):
                    
                    grad_w+=((pred-actual)*X[i][j])
                    
                self.weights[j]-=(2/n)*(self.lr*grad_w)
            
            grad_b=0            
            for pred,actual in zip(y_predicted,y):
                grad_b+=(pred-actual)
            
            self.bias-=(2/n)*self.lr*grad_b
            
            # cost=self.cost(X,y)
            # self.cost_history.append(cost)
            # print(f"epoch {epoch} : grad_w: {self.weights} grad_b: {self.bias}")
            cost = self.cost(X, y)
            r2 = self.r_squared(X, y)
            
            if epoch % print_at == 0:
                print(
                    f"\nEpoch {epoch+1:4d}/{epochs}"
                    f"\n{'─'*62}"
                    f"\nLoss      : {cost:.6f}"
                    f"\nR² Score  : {r2:.6f}"
                    f"\nWeights   : {[round(w,4) for w in self.weights]}"
                    f"\nBias      : {self.bias:.4f}"
                )

# %%
model = LinearRegression(n_features=3,learning_rate=0.01)

# %%
model.fit(X_scaled,y,epochs=10000,print_at=10)
# Out:
# Epoch    1/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5748.213177
# R² Score  : -13.463097
# Weights   : [0.107, 0.1337, 0.124]
# Bias      : 0.1472
#
# Epoch   11/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5126.785747
# R² Score  : -11.899521
# Weights   : [1.1449, 1.4288, 1.3258]
# Bias      : 1.5726
#
# Epoch   21/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4573.216266
# R² Score  : -10.506683
# Weights   : [2.126, 2.6508, 2.4609]
# Bias      : 2.9165
#
# Epoch   31/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4080.092979
# R² Score  : -9.265934
# Weights   : [3.0534, 3.8037, 3.533]
# Bias      : 4.1835
#
# Epoch   41/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 3640.813680
# R² Score  : -8.160662
# Weights   : [3.9303, 4.8914, 4.5457]
# Bias      : 5.3779
#
# Epoch   51/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 3249.497292
# R² Score  : -7.176070
# Weights   : [4.7593, 5.9176, 5.5023]
# Bias      : 6.5039
#
# Epoch   61/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 2900.905102
# R² Score  : -6.298976
# Weights   : [5.5433, 6.8857, 6.406]
# Bias      : 7.5653
#
# Epoch   71/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 2590.370593
# R² Score  : -5.517639
# Weights   : [6.2848, 7.7991, 7.2597]
# Bias      : 8.5657
#
# Epoch   81/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 2313.736954
# R² Score  : -4.821601
# Weights   : [6.986, 8.6607, 8.0663]
# Bias      : 9.5085
#
# Epoch   91/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 2067.301398
# R² Score  : -4.201543
# Weights   : [7.6494, 9.4735, 8.8283]
# Bias      : 10.3969
#
# Epoch  101/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1847.765581
# R² Score  : -3.649169
# Weights   : [8.277, 10.2402, 9.5483]
# Bias      : 11.2341
#
# Epoch  111/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1652.191418
# R² Score  : -3.157084
# Weights   : [8.8708, 10.9635, 10.2287]
# Bias      : 12.0229
#
# Epoch  121/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1477.961738
# R² Score  : -2.718704
# Weights   : [9.4327, 11.6457, 10.8717]
# Bias      : 12.7661
#
# Epoch  131/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1322.745230
# R² Score  : -2.328163
# Weights   : [9.9646, 12.2892, 11.4793]
# Bias      : 13.4661
#
# Epoch  141/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1184.465225
# R² Score  : -1.980237
# Weights   : [10.4681, 12.8961, 12.0536]
# Bias      : 14.1255
#
# Epoch  151/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 1061.271873
# R² Score  : -1.670269
# Weights   : [10.9447, 13.4685, 12.5965]
# Bias      : 14.7465
#
# Epoch  161/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 951.517379
# R² Score  : -1.394116
# Weights   : [11.396, 14.0084, 13.1096]
# Bias      : 15.3312
#
# Epoch  171/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 853.733926
# R² Score  : -1.148083
# Weights   : [11.8235, 14.5176, 13.5947]
# Bias      : 15.8818
#
# Epoch  181/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 766.614021
# R² Score  : -0.928880
# Weights   : [12.2284, 14.9977, 14.0533]
# Bias      : 16.4000
#
# Epoch  191/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 688.992982
# R² Score  : -0.733577
# Weights   : [12.6121, 15.4505, 14.487]
# Bias      : 16.8879
#
# Epoch  201/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 619.833339
# R² Score  : -0.559565
# Weights   : [12.9757, 15.8774, 14.8971]
# Bias      : 17.3469
#
# Epoch  211/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 558.210940
# R² Score  : -0.404516
# Weights   : [13.3203, 16.28, 15.285]
# Bias      : 17.7789
#
# Epoch  221/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 503.302575
# R² Score  : -0.266361
# Weights   : [13.647, 16.6595, 15.6518]
# Bias      : 18.1853
#
# Epoch  231/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 454.374946
# R² Score  : -0.143254
# Weights   : [13.9568, 17.0174, 15.9989]
# Bias      : 18.5675
#
# Epoch  241/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 410.774853
# R² Score  : -0.033552
# Weights   : [14.2507, 17.3547, 16.3272]
# Bias      : 18.9269
#
# Epoch  251/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 371.920441
# R² Score  : 0.064210
# Weights   : [14.5295, 17.6727, 16.6379]
# Bias      : 19.2647
#
# Epoch  261/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 337.293407
# R² Score  : 0.151335
# Weights   : [14.7941, 17.9724, 16.9319]
# Bias      : 19.5823
#
# Epoch  271/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 306.432060
# R² Score  : 0.228985
# Weights   : [15.0454, 18.2549, 17.2102]
# Bias      : 19.8807
#
# Epoch  281/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 278.925138
# R² Score  : 0.298196
# Weights   : [15.2839, 18.5212, 17.4736]
# Bias      : 20.1611
#
# Epoch  291/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 254.406298
# R² Score  : 0.359888
# Weights   : [15.5105, 18.7721, 17.7231]
# Bias      : 20.4243
#
# Epoch  301/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 232.549212
# R² Score  : 0.414882
# Weights   : [15.7259, 19.0085, 17.9593]
# Bias      : 20.6715
#
# Epoch  311/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 213.063195
# R² Score  : 0.463911
# Weights   : [15.9306, 19.2312, 18.183]
# Bias      : 20.9035
#
# Epoch  321/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 195.689310
# R² Score  : 0.507626
# Weights   : [16.1252, 19.4411, 18.3949]
# Bias      : 21.1211
#
# Epoch  331/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 180.196906
# R² Score  : 0.546606
# Weights   : [16.3103, 19.6387, 18.5957]
# Bias      : 21.3252
#
# Epoch  341/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 166.380521
# R² Score  : 0.581369
# Weights   : [16.4865, 19.8249, 18.786]
# Bias      : 21.5165
#
# Epoch  351/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 154.057138
# R² Score  : 0.612376
# Weights   : [16.6543, 20.0002, 18.9664]
# Bias      : 21.6958
#
# Epoch  361/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 143.063726
# R² Score  : 0.640037
# Weights   : [16.814, 20.1653, 19.1374]
# Bias      : 21.8637
#
# Epoch  371/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 133.255065
# R² Score  : 0.664717
# Weights   : [16.9662, 20.3208, 19.2996]
# Bias      : 22.0208
#
# Epoch  381/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 124.501794
# R² Score  : 0.686741
# Weights   : [17.1113, 20.4671, 19.4535]
# Bias      : 22.1678
#
# Epoch  391/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 116.688683
# R² Score  : 0.706399
# Weights   : [17.2497, 20.6048, 19.5995]
# Bias      : 22.3053
#
# Epoch  401/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 109.713086
# R² Score  : 0.723951
# Weights   : [17.3818, 20.7344, 19.7381]
# Bias      : 22.4338
#
# Epoch  411/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 103.483570
# R² Score  : 0.739625
# Weights   : [17.5078, 20.8563, 19.8697]
# Bias      : 22.5537
#
# Epoch  421/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 97.918688
# R² Score  : 0.753626
# Weights   : [17.6282, 20.971, 19.9946]
# Bias      : 22.6656
#
# Epoch  431/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 92.945889
# R² Score  : 0.766139
# Weights   : [17.7433, 21.0789, 20.1133]
# Bias      : 22.7700
#
# Epoch  441/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 88.500546
# R² Score  : 0.777324
# Weights   : [17.8533, 21.1804, 20.2261]
# Bias      : 22.8672
#
# Epoch  451/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 84.525093
# R² Score  : 0.787326
# Weights   : [17.9586, 21.2757, 20.3333]
# Bias      : 22.9576
#
# Epoch  461/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 80.968247
# R² Score  : 0.796276
# Weights   : [18.0594, 21.3654, 20.4353]
# Bias      : 23.0417
#
# Epoch  471/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 77.784331
# R² Score  : 0.804287
# Weights   : [18.1559, 21.4496, 20.5323]
# Bias      : 23.1198
#
# Epoch  481/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 74.932655
# R² Score  : 0.811462
# Weights   : [18.2484, 21.5287, 20.6247]
# Bias      : 23.1922
#
# Epoch  491/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 72.376972
# R² Score  : 0.817892
# Weights   : [18.3372, 21.603, 20.7126]
# Bias      : 23.2592
#
# Epoch  501/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 70.084995
# R² Score  : 0.823659
# Weights   : [18.4223, 21.6727, 20.7963]
# Bias      : 23.3212
#
# Epoch  511/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 68.027965
# R² Score  : 0.828835
# Weights   : [18.5042, 21.7381, 20.8761]
# Bias      : 23.3785
#
# Epoch  521/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 66.180263
# R² Score  : 0.833484
# Weights   : [18.5828, 21.7995, 20.9522]
# Bias      : 23.4313
#
# Epoch  531/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 64.519066
# R² Score  : 0.837663
# Weights   : [18.6584, 21.8571, 21.0247]
# Bias      : 23.4798
#
# Epoch  541/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 63.024046
# R² Score  : 0.841425
# Weights   : [18.7311, 21.9111, 21.094]
# Bias      : 23.5243
#
# Epoch  551/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 61.677096
# R² Score  : 0.844814
# Weights   : [18.8012, 21.9616, 21.1601]
# Bias      : 23.5651
#
# Epoch  561/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 60.462084
# R² Score  : 0.847871
# Weights   : [18.8688, 22.009, 21.2233]
# Bias      : 23.6023
#
# Epoch  571/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 59.364642
# R² Score  : 0.850632
# Weights   : [18.9339, 22.0533, 21.2836]
# Bias      : 23.6362
#
# Epoch  581/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 58.371971
# R² Score  : 0.853130
# Weights   : [18.9968, 22.0947, 21.3414]
# Bias      : 23.6669
#
# Epoch  591/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 57.472668
# R² Score  : 0.855393
# Weights   : [19.0576, 22.1335, 21.3966]
# Bias      : 23.6946
#
# Epoch  601/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 56.656578
# R² Score  : 0.857446
# Weights   : [19.1163, 22.1697, 21.4495]
# Bias      : 23.7195
#
# Epoch  611/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 55.914653
# R² Score  : 0.859313
# Weights   : [19.1732, 22.2035, 21.5002]
# Bias      : 23.7418
#
# Epoch  621/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 55.238835
# R² Score  : 0.861013
# Weights   : [19.2282, 22.235, 21.5488]
# Bias      : 23.7615
#
# Epoch  631/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 54.621944
# R² Score  : 0.862566
# Weights   : [19.2815, 22.2644, 21.5954]
# Bias      : 23.7789
#
# Epoch  641/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 54.057586
# R² Score  : 0.863986
# Weights   : [19.3332, 22.2918, 21.6401]
# Bias      : 23.7940
#
# Epoch  651/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 53.540064
# R² Score  : 0.865288
# Weights   : [19.3834, 22.3172, 21.6831]
# Bias      : 23.8071
#
# Epoch  661/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 53.064303
# R² Score  : 0.866485
# Weights   : [19.4322, 22.3409, 21.7244]
# Bias      : 23.8181
#
# Epoch  671/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 52.625784
# R² Score  : 0.867588
# Weights   : [19.4796, 22.3629, 21.7641]
# Bias      : 23.8273
#
# Epoch  681/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 52.220479
# R² Score  : 0.868608
# Weights   : [19.5257, 22.3832, 21.8023]
# Bias      : 23.8348
#
# Epoch  691/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 51.844801
# R² Score  : 0.869553
# Weights   : [19.5706, 22.4021, 21.8392]
# Bias      : 23.8406
#
# Epoch  701/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 51.495556
# R² Score  : 0.870432
# Weights   : [19.6144, 22.4195, 21.8747]
# Bias      : 23.8448
#
# Epoch  711/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 51.169897
# R² Score  : 0.871251
# Weights   : [19.6571, 22.4356, 21.909]
# Bias      : 23.8475
#
# Epoch  721/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 50.865288
# R² Score  : 0.872018
# Weights   : [19.6987, 22.4504, 21.942]
# Bias      : 23.8489
#
# Epoch  731/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 50.579470
# R² Score  : 0.872737
# Weights   : [19.7394, 22.4641, 21.974]
# Bias      : 23.8489
#
# Epoch  741/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 50.310431
# R² Score  : 0.873414
# Weights   : [19.7792, 22.4766, 22.0049]
# Bias      : 23.8477
#
# Epoch  751/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 50.056379
# R² Score  : 0.874053
# Weights   : [19.8181, 22.488, 22.0348]
# Bias      : 23.8454
#
# Epoch  761/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 49.815717
# R² Score  : 0.874659
# Weights   : [19.8561, 22.4984, 22.0638]
# Bias      : 23.8419
#
# Epoch  771/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 49.587023
# R² Score  : 0.875234
# Weights   : [19.8934, 22.5079, 22.0918]
# Bias      : 23.8374
#
# Epoch  781/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 49.369028
# R² Score  : 0.875782
# Weights   : [19.93, 22.5165, 22.1191]
# Bias      : 23.8320
#
# Epoch  791/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 49.160604
# R² Score  : 0.876307
# Weights   : [19.9659, 22.5242, 22.1455]
# Bias      : 23.8256
#
# Epoch  801/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.960746
# R² Score  : 0.876810
# Weights   : [20.0011, 22.5312, 22.1712]
# Bias      : 23.8183
#
# Epoch  811/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.768557
# R² Score  : 0.877293
# Weights   : [20.0357, 22.5374, 22.1962]
# Bias      : 23.8103
#
# Epoch  821/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.583239
# R² Score  : 0.877760
# Weights   : [20.0697, 22.5429, 22.2205]
# Bias      : 23.8014
#
# Epoch  831/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.404081
# R² Score  : 0.878210
# Weights   : [20.1031, 22.5477, 22.2441]
# Bias      : 23.7919
#
# Epoch  841/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.230449
# R² Score  : 0.878647
# Weights   : [20.136, 22.5519, 22.2672]
# Bias      : 23.7817
#
# Epoch  851/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 48.061779
# R² Score  : 0.879072
# Weights   : [20.1685, 22.5555, 22.2897]
# Bias      : 23.7708
#
# Epoch  861/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.897568
# R² Score  : 0.879485
# Weights   : [20.2004, 22.5586, 22.3116]
# Bias      : 23.7593
#
# Epoch  871/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.737367
# R² Score  : 0.879888
# Weights   : [20.2319, 22.5611, 22.3331]
# Bias      : 23.7473
#
# Epoch  881/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.580778
# R² Score  : 0.880282
# Weights   : [20.263, 22.5631, 22.3541]
# Bias      : 23.7347
#
# Epoch  891/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.427444
# R² Score  : 0.880668
# Weights   : [20.2936, 22.5647, 22.3746]
# Bias      : 23.7217
#
# Epoch  901/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.277049
# R² Score  : 0.881046
# Weights   : [20.3239, 22.5658, 22.3947]
# Bias      : 23.7081
#
# Epoch  911/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 47.129310
# R² Score  : 0.881418
# Weights   : [20.3538, 22.5665, 22.4143]
# Bias      : 23.6941
#
# Epoch  921/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.983975
# R² Score  : 0.881783
# Weights   : [20.3834, 22.5668, 22.4336]
# Bias      : 23.6797
#
# Epoch  931/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.840820
# R² Score  : 0.882144
# Weights   : [20.4126, 22.5667, 22.4526]
# Bias      : 23.6649
#
# Epoch  941/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.699645
# R² Score  : 0.882499
# Weights   : [20.4415, 22.5663, 22.4711]
# Bias      : 23.6498
#
# Epoch  951/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.560271
# R² Score  : 0.882850
# Weights   : [20.4702, 22.5655, 22.4894]
# Bias      : 23.6343
#
# Epoch  961/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.422541
# R² Score  : 0.883196
# Weights   : [20.4985, 22.5645, 22.5074]
# Bias      : 23.6184
#
# Epoch  971/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.286311
# R² Score  : 0.883539
# Weights   : [20.5266, 22.5631, 22.525]
# Bias      : 23.6023
#
# Epoch  981/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.151456
# R² Score  : 0.883878
# Weights   : [20.5544, 22.5615, 22.5424]
# Bias      : 23.5859
#
# Epoch  991/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 46.017864
# R² Score  : 0.884214
# Weights   : [20.582, 22.5596, 22.5595]
# Bias      : 23.5692
#
# Epoch 1001/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.885433
# R² Score  : 0.884548
# Weights   : [20.6094, 22.5575, 22.5764]
# Bias      : 23.5523
#
# Epoch 1011/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.754075
# R² Score  : 0.884878
# Weights   : [20.6365, 22.5551, 22.593]
# Bias      : 23.5351
#
# Epoch 1021/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.623710
# R² Score  : 0.885206
# Weights   : [20.6634, 22.5525, 22.6094]
# Bias      : 23.5177
#
# Epoch 1031/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.494266
# R² Score  : 0.885532
# Weights   : [20.6902, 22.5497, 22.6256]
# Bias      : 23.5001
#
# Epoch 1041/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.365679
# R² Score  : 0.885855
# Weights   : [20.7167, 22.5468, 22.6416]
# Bias      : 23.4823
#
# Epoch 1051/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.237894
# R² Score  : 0.886177
# Weights   : [20.7431, 22.5436, 22.6574]
# Bias      : 23.4643
#
# Epoch 1061/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 45.110859
# R² Score  : 0.886496
# Weights   : [20.7693, 22.5403, 22.673]
# Bias      : 23.4462
#
# Epoch 1071/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.984530
# R² Score  : 0.886814
# Weights   : [20.7953, 22.5368, 22.6885]
# Bias      : 23.4279
#
# Epoch 1081/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.858865
# R² Score  : 0.887130
# Weights   : [20.8212, 22.5332, 22.7038]
# Bias      : 23.4094
#
# Epoch 1091/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.733829
# R² Score  : 0.887445
# Weights   : [20.8469, 22.5294, 22.7189]
# Bias      : 23.3908
#
# Epoch 1101/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.609390
# R² Score  : 0.887758
# Weights   : [20.8725, 22.5255, 22.7339]
# Bias      : 23.3721
#
# Epoch 1111/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.485518
# R² Score  : 0.888070
# Weights   : [20.898, 22.5215, 22.7487]
# Bias      : 23.3533
#
# Epoch 1121/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.362188
# R² Score  : 0.888380
# Weights   : [20.9233, 22.5173, 22.7634]
# Bias      : 23.3343
#
# Epoch 1131/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.239378
# R² Score  : 0.888689
# Weights   : [20.9485, 22.5131, 22.778]
# Bias      : 23.3153
#
# Epoch 1141/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 44.117066
# R² Score  : 0.888997
# Weights   : [20.9735, 22.5087, 22.7924]
# Bias      : 23.2961
#
# Epoch 1151/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.995233
# R² Score  : 0.889303
# Weights   : [20.9985, 22.5042, 22.8068]
# Bias      : 23.2769
#
# Epoch 1161/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.873864
# R² Score  : 0.889609
# Weights   : [21.0233, 22.4997, 22.821]
# Bias      : 23.2576
#
# Epoch 1171/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.752944
# R² Score  : 0.889913
# Weights   : [21.0481, 22.4951, 22.8352]
# Bias      : 23.2382
#
# Epoch 1181/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.632458
# R² Score  : 0.890216
# Weights   : [21.0727, 22.4903, 22.8492]
# Bias      : 23.2187
#
# Epoch 1191/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.512396
# R² Score  : 0.890518
# Weights   : [21.0973, 22.4855, 22.8631]
# Bias      : 23.1992
#
# Epoch 1201/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.392746
# R² Score  : 0.890819
# Weights   : [21.1217, 22.4807, 22.877]
# Bias      : 23.1796
#
# Epoch 1211/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.273499
# R² Score  : 0.891119
# Weights   : [21.1461, 22.4757, 22.8907]
# Bias      : 23.1600
#
# Epoch 1221/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.154646
# R² Score  : 0.891418
# Weights   : [21.1703, 22.4707, 22.9044]
# Bias      : 23.1403
#
# Epoch 1231/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 43.036179
# R² Score  : 0.891717
# Weights   : [21.1945, 22.4657, 22.918]
# Bias      : 23.1206
#
# Epoch 1241/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.918091
# R² Score  : 0.892014
# Weights   : [21.2186, 22.4606, 22.9315]
# Bias      : 23.1008
#
# Epoch 1251/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.800375
# R² Score  : 0.892310
# Weights   : [21.2427, 22.4554, 22.945]
# Bias      : 23.0810
#
# Epoch 1261/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.683027
# R² Score  : 0.892605
# Weights   : [21.2666, 22.4502, 22.9583]
# Bias      : 23.0611
#
# Epoch 1271/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.566040
# R² Score  : 0.892899
# Weights   : [21.2905, 22.445, 22.9717]
# Bias      : 23.0413
#
# Epoch 1281/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.449409
# R² Score  : 0.893193
# Weights   : [21.3143, 22.4397, 22.9849]
# Bias      : 23.0214
#
# Epoch 1291/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.333131
# R² Score  : 0.893485
# Weights   : [21.338, 22.4343, 22.9981]
# Bias      : 23.0014
#
# Epoch 1301/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.217201
# R² Score  : 0.893777
# Weights   : [21.3617, 22.429, 23.0112]
# Bias      : 22.9815
#
# Epoch 1311/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 42.101616
# R² Score  : 0.894068
# Weights   : [21.3853, 22.4236, 23.0243]
# Bias      : 22.9615
#
# Epoch 1321/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.986372
# R² Score  : 0.894358
# Weights   : [21.4089, 22.4181, 23.0373]
# Bias      : 22.9416
#
# Epoch 1331/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.871466
# R² Score  : 0.894647
# Weights   : [21.4324, 22.4127, 23.0503]
# Bias      : 22.9216
#
# Epoch 1341/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.756896
# R² Score  : 0.894935
# Weights   : [21.4558, 22.4072, 23.0632]
# Bias      : 22.9016
#
# Epoch 1351/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.642658
# R² Score  : 0.895223
# Weights   : [21.4792, 22.4017, 23.0761]
# Bias      : 22.8816
#
# Epoch 1361/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.528751
# R² Score  : 0.895509
# Weights   : [21.5025, 22.3961, 23.0889]
# Bias      : 22.8615
#
# Epoch 1371/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.415171
# R² Score  : 0.895795
# Weights   : [21.5257, 22.3906, 23.1017]
# Bias      : 22.8415
#
# Epoch 1381/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.301918
# R² Score  : 0.896080
# Weights   : [21.5489, 22.385, 23.1144]
# Bias      : 22.8215
#
# Epoch 1391/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.188988
# R² Score  : 0.896364
# Weights   : [21.5721, 22.3794, 23.1271]
# Bias      : 22.8015
#
# Epoch 1401/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 41.076381
# R² Score  : 0.896648
# Weights   : [21.5952, 22.3738, 23.1398]
# Bias      : 22.7815
#
# Epoch 1411/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.964094
# R² Score  : 0.896930
# Weights   : [21.6182, 22.3682, 23.1524]
# Bias      : 22.7614
#
# Epoch 1421/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.852126
# R² Score  : 0.897212
# Weights   : [21.6412, 22.3625, 23.1649]
# Bias      : 22.7414
#
# Epoch 1431/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.740475
# R² Score  : 0.897493
# Weights   : [21.6642, 22.3569, 23.1775]
# Bias      : 22.7214
#
# Epoch 1441/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.629140
# R² Score  : 0.897773
# Weights   : [21.6871, 22.3512, 23.19]
# Bias      : 22.7014
#
# Epoch 1451/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.518119
# R² Score  : 0.898052
# Weights   : [21.71, 22.3455, 23.2025]
# Bias      : 22.6814
#
# Epoch 1461/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.407411
# R² Score  : 0.898331
# Weights   : [21.7328, 22.3399, 23.2149]
# Bias      : 22.6614
#
# Epoch 1471/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.297014
# R² Score  : 0.898609
# Weights   : [21.7556, 22.3342, 23.2273]
# Bias      : 22.6414
#
# Epoch 1481/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.186928
# R² Score  : 0.898886
# Weights   : [21.7783, 22.3285, 23.2397]
# Bias      : 22.6215
#
# Epoch 1491/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 40.077151
# R² Score  : 0.899162
# Weights   : [21.801, 22.3228, 23.252]
# Bias      : 22.6015
#
# Epoch 1501/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.967683
# R² Score  : 0.899437
# Weights   : [21.8236, 22.317, 23.2643]
# Bias      : 22.5816
#
# Epoch 1511/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.858521
# R² Score  : 0.899712
# Weights   : [21.8462, 22.3113, 23.2766]
# Bias      : 22.5617
#
# Epoch 1521/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.749665
# R² Score  : 0.899986
# Weights   : [21.8688, 22.3056, 23.2888]
# Bias      : 22.5417
#
# Epoch 1531/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.641113
# R² Score  : 0.900259
# Weights   : [21.8913, 22.2999, 23.3011]
# Bias      : 22.5218
#
# Epoch 1541/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.532866
# R² Score  : 0.900531
# Weights   : [21.9138, 22.2941, 23.3133]
# Bias      : 22.5020
#
# Epoch 1551/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.424921
# R² Score  : 0.900803
# Weights   : [21.9363, 22.2884, 23.3254]
# Bias      : 22.4821
#
# Epoch 1561/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.317278
# R² Score  : 0.901074
# Weights   : [21.9587, 22.2827, 23.3376]
# Bias      : 22.4622
#
# Epoch 1571/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.209935
# R² Score  : 0.901344
# Weights   : [21.9811, 22.2769, 23.3497]
# Bias      : 22.4424
#
# Epoch 1581/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 39.102893
# R² Score  : 0.901613
# Weights   : [22.0034, 22.2712, 23.3618]
# Bias      : 22.4226
#
# Epoch 1591/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.996149
# R² Score  : 0.901882
# Weights   : [22.0257, 22.2655, 23.3738]
# Bias      : 22.4028
#
# Epoch 1601/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.889703
# R² Score  : 0.902149
# Weights   : [22.0479, 22.2597, 23.3859]
# Bias      : 22.3830
#
# Epoch 1611/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.783554
# R² Score  : 0.902417
# Weights   : [22.0702, 22.254, 23.3979]
# Bias      : 22.3633
#
# Epoch 1621/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.677702
# R² Score  : 0.902683
# Weights   : [22.0924, 22.2483, 23.4099]
# Bias      : 22.3435
#
# Epoch 1631/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.572144
# R² Score  : 0.902949
# Weights   : [22.1145, 22.2425, 23.4219]
# Bias      : 22.3238
#
# Epoch 1641/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.466881
# R² Score  : 0.903213
# Weights   : [22.1366, 22.2368, 23.4338]
# Bias      : 22.3041
#
# Epoch 1651/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.361911
# R² Score  : 0.903477
# Weights   : [22.1587, 22.2311, 23.4457]
# Bias      : 22.2844
#
# Epoch 1661/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.257234
# R² Score  : 0.903741
# Weights   : [22.1808, 22.2254, 23.4576]
# Bias      : 22.2648
#
# Epoch 1671/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.152849
# R² Score  : 0.904003
# Weights   : [22.2028, 22.2196, 23.4695]
# Bias      : 22.2452
#
# Epoch 1681/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 38.048755
# R² Score  : 0.904265
# Weights   : [22.2248, 22.2139, 23.4814]
# Bias      : 22.2256
#
# Epoch 1691/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.944950
# R² Score  : 0.904527
# Weights   : [22.2467, 22.2082, 23.4932]
# Bias      : 22.2060
#
# Epoch 1701/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.841435
# R² Score  : 0.904787
# Weights   : [22.2686, 22.2025, 23.505]
# Bias      : 22.1864
#
# Epoch 1711/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.738208
# R² Score  : 0.905047
# Weights   : [22.2905, 22.1968, 23.5168]
# Bias      : 22.1669
#
# Epoch 1721/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.635269
# R² Score  : 0.905306
# Weights   : [22.3124, 22.1911, 23.5286]
# Bias      : 22.1473
#
# Epoch 1731/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.532617
# R² Score  : 0.905564
# Weights   : [22.3342, 22.1854, 23.5404]
# Bias      : 22.1279
#
# Epoch 1741/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.430250
# R² Score  : 0.905822
# Weights   : [22.3559, 22.1797, 23.5521]
# Bias      : 22.1084
#
# Epoch 1751/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.328169
# R² Score  : 0.906078
# Weights   : [22.3777, 22.174, 23.5638]
# Bias      : 22.0889
#
# Epoch 1761/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.226372
# R² Score  : 0.906335
# Weights   : [22.3994, 22.1683, 23.5755]
# Bias      : 22.0695
#
# Epoch 1771/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.124858
# R² Score  : 0.906590
# Weights   : [22.4211, 22.1626, 23.5872]
# Bias      : 22.0501
#
# Epoch 1781/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 37.023627
# R² Score  : 0.906845
# Weights   : [22.4428, 22.157, 23.5989]
# Bias      : 22.0307
#
# Epoch 1791/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.922678
# R² Score  : 0.907099
# Weights   : [22.4644, 22.1513, 23.6105]
# Bias      : 22.0114
#
# Epoch 1801/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.822010
# R² Score  : 0.907352
# Weights   : [22.486, 22.1456, 23.6221]
# Bias      : 21.9921
#
# Epoch 1811/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.721622
# R² Score  : 0.907605
# Weights   : [22.5075, 22.14, 23.6337]
# Bias      : 21.9728
#
# Epoch 1821/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.621514
# R² Score  : 0.907856
# Weights   : [22.5291, 22.1343, 23.6453]
# Bias      : 21.9535
#
# Epoch 1831/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.521685
# R² Score  : 0.908108
# Weights   : [22.5505, 22.1287, 23.6569]
# Bias      : 21.9342
#
# Epoch 1841/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.422133
# R² Score  : 0.908358
# Weights   : [22.572, 22.123, 23.6684]
# Bias      : 21.9150
#
# Epoch 1851/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.322859
# R² Score  : 0.908608
# Weights   : [22.5934, 22.1174, 23.6799]
# Bias      : 21.8958
#
# Epoch 1861/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.223861
# R² Score  : 0.908857
# Weights   : [22.6149, 22.1118, 23.6914]
# Bias      : 21.8766
#
# Epoch 1871/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.125139
# R² Score  : 0.909105
# Weights   : [22.6362, 22.1061, 23.7029]
# Bias      : 21.8575
#
# Epoch 1881/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 36.026692
# R² Score  : 0.909353
# Weights   : [22.6576, 22.1005, 23.7144]
# Bias      : 21.8383
#
# Epoch 1891/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.928518
# R² Score  : 0.909600
# Weights   : [22.6789, 22.0949, 23.7259]
# Bias      : 21.8192
#
# Epoch 1901/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.830618
# R² Score  : 0.909846
# Weights   : [22.7002, 22.0893, 23.7373]
# Bias      : 21.8002
#
# Epoch 1911/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.732991
# R² Score  : 0.910092
# Weights   : [22.7214, 22.0837, 23.7487]
# Bias      : 21.7811
#
# Epoch 1921/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.635635
# R² Score  : 0.910337
# Weights   : [22.7426, 22.0781, 23.7601]
# Bias      : 21.7621
#
# Epoch 1931/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.538551
# R² Score  : 0.910581
# Weights   : [22.7638, 22.0725, 23.7715]
# Bias      : 21.7431
#
# Epoch 1941/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.441737
# R² Score  : 0.910825
# Weights   : [22.785, 22.067, 23.7829]
# Bias      : 21.7241
#
# Epoch 1951/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.345192
# R² Score  : 0.911068
# Weights   : [22.8061, 22.0614, 23.7942]
# Bias      : 21.7052
#
# Epoch 1961/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.248916
# R² Score  : 0.911310
# Weights   : [22.8272, 22.0558, 23.8056]
# Bias      : 21.6862
#
# Epoch 1971/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.152908
# R² Score  : 0.911552
# Weights   : [22.8483, 22.0503, 23.8169]
# Bias      : 21.6673
#
# Epoch 1981/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 35.057167
# R² Score  : 0.911793
# Weights   : [22.8693, 22.0447, 23.8282]
# Bias      : 21.6485
#
# Epoch 1991/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.961693
# R² Score  : 0.912033
# Weights   : [22.8903, 22.0392, 23.8395]
# Bias      : 21.6296
#
# Epoch 2001/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.866485
# R² Score  : 0.912272
# Weights   : [22.9113, 22.0337, 23.8507]
# Bias      : 21.6108
#
# Epoch 2011/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.771541
# R² Score  : 0.912511
# Weights   : [22.9323, 22.0281, 23.862]
# Bias      : 21.5920
#
# Epoch 2021/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.676862
# R² Score  : 0.912749
# Weights   : [22.9532, 22.0226, 23.8732]
# Bias      : 21.5732
#
# Epoch 2031/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.582447
# R² Score  : 0.912987
# Weights   : [22.9741, 22.0171, 23.8844]
# Bias      : 21.5545
#
# Epoch 2041/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.488294
# R² Score  : 0.913224
# Weights   : [22.995, 22.0116, 23.8956]
# Bias      : 21.5358
#
# Epoch 2051/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.394404
# R² Score  : 0.913460
# Weights   : [23.0158, 22.0061, 23.9068]
# Bias      : 21.5171
#
# Epoch 2061/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.300775
# R² Score  : 0.913696
# Weights   : [23.0366, 22.0006, 23.918]
# Bias      : 21.4984
#
# Epoch 2071/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.207406
# R² Score  : 0.913931
# Weights   : [23.0574, 21.9951, 23.9291]
# Bias      : 21.4798
#
# Epoch 2081/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.114297
# R² Score  : 0.914165
# Weights   : [23.0782, 21.9896, 23.9403]
# Bias      : 21.4611
#
# Epoch 2091/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 34.021448
# R² Score  : 0.914399
# Weights   : [23.0989, 21.9841, 23.9514]
# Bias      : 21.4425
#
# Epoch 2101/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.928857
# R² Score  : 0.914631
# Weights   : [23.1196, 21.9787, 23.9625]
# Bias      : 21.4240
#
# Epoch 2111/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.836524
# R² Score  : 0.914864
# Weights   : [23.1402, 21.9732, 23.9735]
# Bias      : 21.4054
#
# Epoch 2121/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.744448
# R² Score  : 0.915095
# Weights   : [23.1609, 21.9678, 23.9846]
# Bias      : 21.3869
#
# Epoch 2131/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.652628
# R² Score  : 0.915327
# Weights   : [23.1815, 21.9623, 23.9957]
# Bias      : 21.3684
#
# Epoch 2141/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.561064
# R² Score  : 0.915557
# Weights   : [23.2021, 21.9569, 24.0067]
# Bias      : 21.3500
#
# Epoch 2151/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.469755
# R² Score  : 0.915787
# Weights   : [23.2226, 21.9515, 24.0177]
# Bias      : 21.3315
#
# Epoch 2161/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.378700
# R² Score  : 0.916016
# Weights   : [23.2431, 21.946, 24.0287]
# Bias      : 21.3131
#
# Epoch 2171/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.287898
# R² Score  : 0.916244
# Weights   : [23.2636, 21.9406, 24.0397]
# Bias      : 21.2947
#
# Epoch 2181/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.197349
# R² Score  : 0.916472
# Weights   : [23.2841, 21.9352, 24.0507]
# Bias      : 21.2764
#
# Epoch 2191/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.107052
# R² Score  : 0.916699
# Weights   : [23.3045, 21.9298, 24.0616]
# Bias      : 21.2580
#
# Epoch 2201/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 33.017007
# R² Score  : 0.916926
# Weights   : [23.3249, 21.9244, 24.0726]
# Bias      : 21.2397
#
# Epoch 2211/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.927212
# R² Score  : 0.917152
# Weights   : [23.3453, 21.919, 24.0835]
# Bias      : 21.2214
#
# Epoch 2221/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.837667
# R² Score  : 0.917377
# Weights   : [23.3657, 21.9137, 24.0944]
# Bias      : 21.2032
#
# Epoch 2231/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.748372
# R² Score  : 0.917602
# Weights   : [23.386, 21.9083, 24.1053]
# Bias      : 21.1849
#
# Epoch 2241/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.659325
# R² Score  : 0.917826
# Weights   : [23.4063, 21.9029, 24.1162]
# Bias      : 21.1667
#
# Epoch 2251/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.570526
# R² Score  : 0.918049
# Weights   : [23.4265, 21.8976, 24.127]
# Bias      : 21.1485
#
# Epoch 2261/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.481974
# R² Score  : 0.918272
# Weights   : [23.4468, 21.8922, 24.1379]
# Bias      : 21.1304
#
# Epoch 2271/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.393669
# R² Score  : 0.918494
# Weights   : [23.467, 21.8869, 24.1487]
# Bias      : 21.1122
#
# Epoch 2281/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.305609
# R² Score  : 0.918716
# Weights   : [23.4872, 21.8816, 24.1595]
# Bias      : 21.0941
#
# Epoch 2291/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.217795
# R² Score  : 0.918937
# Weights   : [23.5073, 21.8762, 24.1703]
# Bias      : 21.0761
#
# Epoch 2301/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.130225
# R² Score  : 0.919157
# Weights   : [23.5275, 21.8709, 24.1811]
# Bias      : 21.0580
#
# Epoch 2311/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 32.042898
# R² Score  : 0.919377
# Weights   : [23.5476, 21.8656, 24.1918]
# Bias      : 21.0400
#
# Epoch 2321/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.955815
# R² Score  : 0.919596
# Weights   : [23.5676, 21.8603, 24.2026]
# Bias      : 21.0220
#
# Epoch 2331/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.868975
# R² Score  : 0.919814
# Weights   : [23.5877, 21.855, 24.2133]
# Bias      : 21.0040
#
# Epoch 2341/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.782376
# R² Score  : 0.920032
# Weights   : [23.6077, 21.8497, 24.224]
# Bias      : 20.9860
#
# Epoch 2351/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.696018
# R² Score  : 0.920250
# Weights   : [23.6277, 21.8444, 24.2347]
# Bias      : 20.9681
#
# Epoch 2361/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.609900
# R² Score  : 0.920466
# Weights   : [23.6477, 21.8391, 24.2454]
# Bias      : 20.9502
#
# Epoch 2371/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.524023
# R² Score  : 0.920682
# Weights   : [23.6676, 21.8339, 24.2561]
# Bias      : 20.9323
#
# Epoch 2381/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.438384
# R² Score  : 0.920898
# Weights   : [23.6875, 21.8286, 24.2667]
# Bias      : 20.9144
#
# Epoch 2391/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.352984
# R² Score  : 0.921113
# Weights   : [23.7074, 21.8234, 24.2774]
# Bias      : 20.8966
#
# Epoch 2401/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.267821
# R² Score  : 0.921327
# Weights   : [23.7272, 21.8181, 24.288]
# Bias      : 20.8788
#
# Epoch 2411/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.182896
# R² Score  : 0.921541
# Weights   : [23.7471, 21.8129, 24.2986]
# Bias      : 20.8610
#
# Epoch 2421/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.098206
# R² Score  : 0.921754
# Weights   : [23.7669, 21.8076, 24.3092]
# Bias      : 20.8433
#
# Epoch 2431/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 31.013753
# R² Score  : 0.921966
# Weights   : [23.7866, 21.8024, 24.3198]
# Bias      : 20.8255
#
# Epoch 2441/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.929535
# R² Score  : 0.922178
# Weights   : [23.8064, 21.7972, 24.3303]
# Bias      : 20.8078
#
# Epoch 2451/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.845551
# R² Score  : 0.922389
# Weights   : [23.8261, 21.792, 24.3409]
# Bias      : 20.7901
#
# Epoch 2461/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.761801
# R² Score  : 0.922600
# Weights   : [23.8458, 21.7868, 24.3514]
# Bias      : 20.7725
#
# Epoch 2471/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.678284
# R² Score  : 0.922810
# Weights   : [23.8655, 21.7816, 24.3619]
# Bias      : 20.7548
#
# Epoch 2481/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.595000
# R² Score  : 0.923020
# Weights   : [23.8851, 21.7764, 24.3724]
# Bias      : 20.7372
#
# Epoch 2491/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.511947
# R² Score  : 0.923229
# Weights   : [23.9047, 21.7712, 24.3829]
# Bias      : 20.7196
#
# Epoch 2501/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.429126
# R² Score  : 0.923437
# Weights   : [23.9243, 21.766, 24.3934]
# Bias      : 20.7021
#
# Epoch 2511/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.346535
# R² Score  : 0.923645
# Weights   : [23.9438, 21.7609, 24.4038]
# Bias      : 20.6845
#
# Epoch 2521/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.264174
# R² Score  : 0.923852
# Weights   : [23.9634, 21.7557, 24.4143]
# Bias      : 20.6670
#
# Epoch 2531/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.182042
# R² Score  : 0.924059
# Weights   : [23.9829, 21.7506, 24.4247]
# Bias      : 20.6495
#
# Epoch 2541/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.100139
# R² Score  : 0.924265
# Weights   : [24.0024, 21.7454, 24.4351]
# Bias      : 20.6321
#
# Epoch 2551/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 30.018464
# R² Score  : 0.924470
# Weights   : [24.0218, 21.7403, 24.4455]
# Bias      : 20.6146
#
# Epoch 2561/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 29.937017
# R² Score  : 0.924675
# Weights   : [24.0412, 21.7351, 24.4559]
# Bias      : 20.5972
#
# Epoch 2571/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 29.855796
# R² Score  : 0.924880
# Weights   : [24.0606, 21.73, 24.4663]
# Bias      : 20.5798
#
# Epoch 2581/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 29.774801
# R² Score  : 0.925084
# Weights   : [24.08, 21.7249, 24.4766]
# Bias      : 20.5625
#
# Epoch 2591/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 29.694031
# R² Score  : 0.925287
# Weights   : [24.0993, 21.7198, 24.4869]
# Bias      : 20.5451
#
# Epoch 2601/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 29.613487
# R² Score  : 0.925489
# Weights   : [24.1186, 21.7147, 24.4973]
# Bias      : 20.5278
#
# ...
# Loss      : 5.442271
# R² Score  : 0.986307
# Weights   : [32.4535, 19.5283, 28.8289]
# Bias      : 13.1403
#
# Epoch 9131/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.429211
# R² Score  : 0.986340
# Weights   : [32.4614, 19.5262, 28.8329]
# Bias      : 13.1334
#
# Epoch 9141/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.416187
# R² Score  : 0.986372
# Weights   : [32.4694, 19.5241, 28.8368]
# Bias      : 13.1265
#
# Epoch 9151/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.403199
# R² Score  : 0.986405
# Weights   : [32.4773, 19.5221, 28.8407]
# Bias      : 13.1196
#
# Epoch 9161/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.390248
# R² Score  : 0.986438
# Weights   : [32.4852, 19.52, 28.8446]
# Bias      : 13.1127
#
# Epoch 9171/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.377332
# R² Score  : 0.986470
# Weights   : [32.4931, 19.518, 28.8485]
# Bias      : 13.1058
#
# Epoch 9181/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.364452
# R² Score  : 0.986502
# Weights   : [32.501, 19.5159, 28.8524]
# Bias      : 13.0990
#
# Epoch 9191/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.351608
# R² Score  : 0.986535
# Weights   : [32.5089, 19.5139, 28.8563]
# Bias      : 13.0921
#
# Epoch 9201/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.338800
# R² Score  : 0.986567
# Weights   : [32.5168, 19.5119, 28.8602]
# Bias      : 13.0853
#
# Epoch 9211/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.326028
# R² Score  : 0.986599
# Weights   : [32.5247, 19.5098, 28.8641]
# Bias      : 13.0785
#
# Epoch 9221/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.313290
# R² Score  : 0.986631
# Weights   : [32.5325, 19.5078, 28.868]
# Bias      : 13.0716
#
# Epoch 9231/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.300589
# R² Score  : 0.986663
# Weights   : [32.5404, 19.5058, 28.8718]
# Bias      : 13.0648
#
# Epoch 9241/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.287922
# R² Score  : 0.986695
# Weights   : [32.5482, 19.5037, 28.8757]
# Bias      : 13.0580
#
# Epoch 9251/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.275291
# R² Score  : 0.986727
# Weights   : [32.556, 19.5017, 28.8795]
# Bias      : 13.0512
#
# Epoch 9261/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.262695
# R² Score  : 0.986759
# Weights   : [32.5638, 19.4997, 28.8834]
# Bias      : 13.0445
#
# Epoch 9271/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.250134
# R² Score  : 0.986790
# Weights   : [32.5716, 19.4977, 28.8872]
# Bias      : 13.0377
#
# Epoch 9281/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.237608
# R² Score  : 0.986822
# Weights   : [32.5794, 19.4957, 28.8911]
# Bias      : 13.0309
#
# Epoch 9291/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.225116
# R² Score  : 0.986853
# Weights   : [32.5872, 19.4936, 28.8949]
# Bias      : 13.0242
#
# Epoch 9301/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.212660
# R² Score  : 0.986884
# Weights   : [32.595, 19.4916, 28.8987]
# Bias      : 13.0174
#
# Epoch 9311/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.200238
# R² Score  : 0.986916
# Weights   : [32.6028, 19.4896, 28.9026]
# Bias      : 13.0107
#
# Epoch 9321/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.187850
# R² Score  : 0.986947
# Weights   : [32.6105, 19.4876, 28.9064]
# Bias      : 13.0040
#
# Epoch 9331/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.175497
# R² Score  : 0.986978
# Weights   : [32.6182, 19.4856, 28.9102]
# Bias      : 12.9973
#
# Epoch 9341/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.163178
# R² Score  : 0.987009
# Weights   : [32.626, 19.4836, 28.914]
# Bias      : 12.9906
#
# Epoch 9351/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.150894
# R² Score  : 0.987040
# Weights   : [32.6337, 19.4816, 28.9178]
# Bias      : 12.9839
#
# Epoch 9361/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.138643
# R² Score  : 0.987071
# Weights   : [32.6414, 19.4796, 28.9216]
# Bias      : 12.9772
#
# Epoch 9371/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.126427
# R² Score  : 0.987101
# Weights   : [32.6491, 19.4776, 28.9254]
# Bias      : 12.9705
#
# Epoch 9381/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.114245
# R² Score  : 0.987132
# Weights   : [32.6568, 19.4756, 28.9292]
# Bias      : 12.9639
#
# Epoch 9391/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.102096
# R² Score  : 0.987163
# Weights   : [32.6645, 19.4737, 28.9329]
# Bias      : 12.9572
#
# Epoch 9401/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.089981
# R² Score  : 0.987193
# Weights   : [32.6722, 19.4717, 28.9367]
# Bias      : 12.9505
#
# Epoch 9411/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.077900
# R² Score  : 0.987223
# Weights   : [32.6798, 19.4697, 28.9405]
# Bias      : 12.9439
#
# Epoch 9421/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.065853
# R² Score  : 0.987254
# Weights   : [32.6875, 19.4677, 28.9442]
# Bias      : 12.9373
#
# Epoch 9431/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.053838
# R² Score  : 0.987284
# Weights   : [32.6951, 19.4657, 28.948]
# Bias      : 12.9307
#
# Epoch 9441/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.041858
# R² Score  : 0.987314
# Weights   : [32.7027, 19.4638, 28.9517]
# Bias      : 12.9241
#
# Epoch 9451/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.029910
# R² Score  : 0.987344
# Weights   : [32.7103, 19.4618, 28.9555]
# Bias      : 12.9175
#
# Epoch 9461/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.017996
# R² Score  : 0.987374
# Weights   : [32.718, 19.4598, 28.9592]
# Bias      : 12.9109
#
# Epoch 9471/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 5.006115
# R² Score  : 0.987404
# Weights   : [32.7256, 19.4579, 28.9629]
# Bias      : 12.9043
#
# Epoch 9481/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.994267
# R² Score  : 0.987434
# Weights   : [32.7331, 19.4559, 28.9667]
# Bias      : 12.8977
#
# Epoch 9491/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.982452
# R² Score  : 0.987464
# Weights   : [32.7407, 19.4539, 28.9704]
# Bias      : 12.8911
#
# Epoch 9501/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.970670
# R² Score  : 0.987493
# Weights   : [32.7483, 19.452, 28.9741]
# Bias      : 12.8846
#
# Epoch 9511/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.958920
# R² Score  : 0.987523
# Weights   : [32.7558, 19.45, 28.9778]
# Bias      : 12.8780
#
# Epoch 9521/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.947203
# R² Score  : 0.987552
# Weights   : [32.7634, 19.4481, 28.9815]
# Bias      : 12.8715
#
# Epoch 9531/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.935519
# R² Score  : 0.987582
# Weights   : [32.7709, 19.4461, 28.9852]
# Bias      : 12.8650
#
# Epoch 9541/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.923867
# R² Score  : 0.987611
# Weights   : [32.7785, 19.4442, 28.9889]
# Bias      : 12.8585
#
# Epoch 9551/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.912247
# R² Score  : 0.987640
# Weights   : [32.786, 19.4423, 28.9926]
# Bias      : 12.8520
#
# Epoch 9561/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.900660
# R² Score  : 0.987669
# Weights   : [32.7935, 19.4403, 28.9962]
# Bias      : 12.8455
#
# Epoch 9571/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.889105
# R² Score  : 0.987699
# Weights   : [32.801, 19.4384, 28.9999]
# Bias      : 12.8390
#
# Epoch 9581/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.877582
# R² Score  : 0.987728
# Weights   : [32.8085, 19.4364, 29.0036]
# Bias      : 12.8325
#
# Epoch 9591/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.866091
# R² Score  : 0.987756
# Weights   : [32.8159, 19.4345, 29.0072]
# Bias      : 12.8260
#
# Epoch 9601/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.854632
# R² Score  : 0.987785
# Weights   : [32.8234, 19.4326, 29.0109]
# Bias      : 12.8196
#
# Epoch 9611/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.843205
# R² Score  : 0.987814
# Weights   : [32.8309, 19.4307, 29.0146]
# Bias      : 12.8131
#
# Epoch 9621/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.831810
# R² Score  : 0.987843
# Weights   : [32.8383, 19.4287, 29.0182]
# Bias      : 12.8067
#
# Epoch 9631/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.820446
# R² Score  : 0.987871
# Weights   : [32.8458, 19.4268, 29.0218]
# Bias      : 12.8002
#
# Epoch 9641/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.809114
# R² Score  : 0.987900
# Weights   : [32.8532, 19.4249, 29.0255]
# Bias      : 12.7938
#
# Epoch 9651/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.797813
# R² Score  : 0.987928
# Weights   : [32.8606, 19.423, 29.0291]
# Bias      : 12.7874
#
# Epoch 9661/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.786544
# R² Score  : 0.987957
# Weights   : [32.868, 19.4211, 29.0327]
# Bias      : 12.7810
#
# Epoch 9671/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.775306
# R² Score  : 0.987985
# Weights   : [32.8754, 19.4192, 29.0363]
# Bias      : 12.7746
#
# Epoch 9681/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.764099
# R² Score  : 0.988013
# Weights   : [32.8828, 19.4172, 29.04]
# Bias      : 12.7682
#
# Epoch 9691/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.752924
# R² Score  : 0.988041
# Weights   : [32.8902, 19.4153, 29.0436]
# Bias      : 12.7618
#
# Epoch 9701/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.741779
# R² Score  : 0.988069
# Weights   : [32.8975, 19.4134, 29.0472]
# Bias      : 12.7555
#
# Epoch 9711/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.730666
# R² Score  : 0.988097
# Weights   : [32.9049, 19.4115, 29.0508]
# Bias      : 12.7491
#
# Epoch 9721/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.719583
# R² Score  : 0.988125
# Weights   : [32.9122, 19.4096, 29.0543]
# Bias      : 12.7427
#
# Epoch 9731/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.708531
# R² Score  : 0.988153
# Weights   : [32.9196, 19.4077, 29.0579]
# Bias      : 12.7364
#
# Epoch 9741/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.697510
# R² Score  : 0.988181
# Weights   : [32.9269, 19.4059, 29.0615]
# Bias      : 12.7301
#
# Epoch 9751/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.686519
# R² Score  : 0.988208
# Weights   : [32.9342, 19.404, 29.0651]
# Bias      : 12.7237
#
# Epoch 9761/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.675559
# R² Score  : 0.988236
# Weights   : [32.9415, 19.4021, 29.0686]
# Bias      : 12.7174
#
# Epoch 9771/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.664630
# R² Score  : 0.988263
# Weights   : [32.9488, 19.4002, 29.0722]
# Bias      : 12.7111
#
# Epoch 9781/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.653731
# R² Score  : 0.988291
# Weights   : [32.9561, 19.3983, 29.0758]
# Bias      : 12.7048
#
# Epoch 9791/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.642862
# R² Score  : 0.988318
# Weights   : [32.9634, 19.3964, 29.0793]
# Bias      : 12.6985
#
# Epoch 9801/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.632023
# R² Score  : 0.988345
# Weights   : [32.9707, 19.3946, 29.0829]
# Bias      : 12.6922
#
# Epoch 9811/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.621214
# R² Score  : 0.988373
# Weights   : [32.9779, 19.3927, 29.0864]
# Bias      : 12.6860
#
# Epoch 9821/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.610436
# R² Score  : 0.988400
# Weights   : [32.9852, 19.3908, 29.0899]
# Bias      : 12.6797
#
# Epoch 9831/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.599687
# R² Score  : 0.988427
# Weights   : [32.9924, 19.3889, 29.0935]
# Bias      : 12.6734
#
# Epoch 9841/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.588968
# R² Score  : 0.988454
# Weights   : [32.9997, 19.3871, 29.097]
# Bias      : 12.6672
#
# Epoch 9851/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.578279
# R² Score  : 0.988481
# Weights   : [33.0069, 19.3852, 29.1005]
# Bias      : 12.6610
#
# Epoch 9861/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.567620
# R² Score  : 0.988507
# Weights   : [33.0141, 19.3834, 29.104]
# Bias      : 12.6547
#
# Epoch 9871/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.556990
# R² Score  : 0.988534
# Weights   : [33.0213, 19.3815, 29.1075]
# Bias      : 12.6485
#
# Epoch 9881/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.546390
# R² Score  : 0.988561
# Weights   : [33.0285, 19.3796, 29.111]
# Bias      : 12.6423
#
# Epoch 9891/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.535820
# R² Score  : 0.988587
# Weights   : [33.0357, 19.3778, 29.1145]
# Bias      : 12.6361
#
# Epoch 9901/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.525278
# R² Score  : 0.988614
# Weights   : [33.0428, 19.3759, 29.118]
# Bias      : 12.6299
#
# Epoch 9911/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.514766
# R² Score  : 0.988640
# Weights   : [33.05, 19.3741, 29.1215]
# Bias      : 12.6237
#
# Epoch 9921/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.504283
# R² Score  : 0.988667
# Weights   : [33.0572, 19.3722, 29.125]
# Bias      : 12.6176
#
# Epoch 9931/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.493830
# R² Score  : 0.988693
# Weights   : [33.0643, 19.3704, 29.1285]
# Bias      : 12.6114
#
# Epoch 9941/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.483405
# R² Score  : 0.988719
# Weights   : [33.0714, 19.3686, 29.1319]
# Bias      : 12.6052
#
# Epoch 9951/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.473009
# R² Score  : 0.988745
# Weights   : [33.0786, 19.3667, 29.1354]
# Bias      : 12.5991
#
# Epoch 9961/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.462642
# R² Score  : 0.988772
# Weights   : [33.0857, 19.3649, 29.1389]
# Bias      : 12.5929
#
# Epoch 9971/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.452304
# R² Score  : 0.988798
# Weights   : [33.0928, 19.3631, 29.1423]
# Bias      : 12.5868
#
# Epoch 9981/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.441995
# R² Score  : 0.988823
# Weights   : [33.0999, 19.3612, 29.1458]
# Bias      : 12.5807
#
# Epoch 9991/10000
# ──────────────────────────────────────────────────────────────
# Loss      : 4.431714
# R² Score  : 0.988849
# Weights   : [33.107, 19.3594, 29.1492]
# Bias      : 12.5746

# %%
model.predict(X_test_scaled)
# Out:
# [46.4459164321192,
#  53.83394585552896,
#  61.02839771915133,
#  68.02927202298629,
#  75.03014632682125,
#  81.83744307086882,
#  88.45116225512896,
#  92.3432295760425]

# %%
model.bias
# Out:
# -1.3399063875307975e+158

# %%
model.predict_single([1,2,3])
# Out:
# 0.0

# %%
model.predict([[1,2,3],[1,2,3],[1,2,3],[1,2,3]])
# Out:
# [0.0, 0.0, 0.0, 0.0]

# %%
for i,x,y in zip([2,3],[1,2],range(2)):
    print(i,x,y)
# Out:
# 2 1 0
# 3 2 1

# %%
from sklearn.linear_model import LinearRegression
model_sk=LinearRegression()

# %%
model_sk.fit(X_scaled,y)
# Out:
# LinearRegression()

# %%
model_sk.predict(X_test_scaled)
# Out:
# array([43.75439367, 51.59731986, 59.31612478, 66.91080844, 74.50549209,
#        81.97605448, 89.32249561, 94.00329525])

# %%
X = [
    [2, 70, 3],
    [3, 75, 5],
    [4, 80, 6],
    [5, 85, 7],
    [6, 90, 8],
    [7, 92, 9],
    [8, 95, 10],
    [9, 97, 10],
    [10, 98, 10],
    [11, 100, 10],
]

y = [
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    92,
    96,
    100,
]


X_test = [
    [2.5, 72, 4],
    [3.5, 78, 5],
    [4.5, 83, 6],
    [5.5, 87, 7],
    [6.5, 91, 8],
    [7.5, 94, 9],
    [8.5, 96, 10],
    [9.5, 99, 10],
]

# Expected Marks
y_test = [
    44,
    52,
    60,
    68,
    76,
    84,
    90,
    98,
]

# %%
import random

class MultipleLinearRegression:
    def __init__(self, n_features, learning_rate=0.01):
        self.weights = [0.0] * n_features
        self.bias = 0.0
        self.lr = learning_rate
        self.cost_history = []

    def predict_single(self, x):
        return sum(w * xi for w, xi in zip(self.weights, x)) + self.bias

    def predict(self, X):
        return [self.predict_single(x) for x in X]

    def compute_cost(self, X, y):
        predictions = self.predict(X)
        n = len(y)
        return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n

    def fit(self, X, y, epochs=1000, print_every=200):
        n = len(y)
        n_features = len(X[0])
        for epoch in range(epochs):
            predictions = self.predict(X)
            errors = [pred - actual for pred, actual in zip(predictions, y)]
            for j in range(n_features):
                grad = (2 / n) * sum(errors[i] * X[i][j] for i in range(n))
                self.weights[j] -= self.lr * grad
            grad_b = (2 / n) * sum(errors)
            self.bias -= self.lr * grad_b
            cost = self.compute_cost(X, y)
            self.cost_history.append(cost)
            if epoch % print_every == 0:
                print(f"  Epoch {epoch:4d} | Cost: {cost:.4f}")
        return self

    def r_squared(self, X, y):
        predictions = self.predict(X)
        y_mean = sum(y) / len(y)
        ss_res = sum((actual - pred) ** 2 for actual, pred in zip(y, predictions))
        ss_tot = sum((actual - y_mean) ** 2 for actual in y)
        return 1 - (ss_res / ss_tot)


random.seed(42)
N = 100
X_multi = []
y_multi = []
for _ in range(N):
    size = random.uniform(500, 3000)
    bedrooms = random.randint(1, 5)
    age = random.uniform(0, 50)
    price = 50 * size + 10000 * bedrooms - 1000 * age + 50000 + random.gauss(0, 20000)
    X_multi.append([size, bedrooms, age])
    y_multi.append(price)


def standardize(X):
    n_features = len(X[0])
    means = [sum(X[i][j] for i in range(len(X))) / len(X) for j in range(n_features)]
    stds = []
    for j in range(n_features):
        variance = sum((X[i][j] - means[j]) ** 2 for i in range(len(X))) / len(X)
        stds.append(variance ** 0.5)
    X_scaled = []
    for i in range(len(X)):
        row = [(X[i][j] - means[j]) / stds[j] if stds[j] > 0 else 0 for j in range(n_features)]
        X_scaled.append(row)
    return X_scaled, means, stds

# %%
model_aie=MultipleLinearRegression(n_features=3)

# %%
model_aie.fit(X,y)
# Out:
#   Epoch    0 | Cost: 143116825.9023
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model_aie.fit(X,y)
#
# Cell In[13], line 32, in MultipleLinearRegression.fit(self, X, y, epochs, print_every)
#      28                 grad = (2 / n) * sum(errors[i] * X[i][j] for i in range(n))
#      29                 self.weights[j] -= self.lr * grad
#      30             grad_b = (2 / n) * sum(errors)
#      31             self.bias -= self.lr * grad_b
# ---> 32             cost = self.compute_cost(X, y)
#      33             self.cost_history.append(cost)
#      34             if epoch % print_every == 0:
#      35                 print(f"  Epoch {epoch:4d} | Cost: {cost:.4f}")
#
# Cell In[13], line 19, in MultipleLinearRegression.compute_cost(self, X, y)
#      16     def compute_cost(self, X, y):
#      17         predictions = self.predict(X)
#      18         n = len(y)
# ---> 19         return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n
#
# Cell In[13], line 19, in MultipleLinearRegression.compute_cost.<locals>.<genexpr>(.0)
# ---> 19     def compute_cost(self, X, y):
#      20         predictions = self.predict(X)
#      21         n = len(y)
#      22         return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n
#
# OverflowError: (34, 'Result too large')

# %%
import random

class MultipleLinearRegression:
    def __init__(self, n_features, learning_rate=0.01):
        self.weights = [0.0] * n_features
        self.bias = 0.0
        self.lr = learning_rate
        self.cost_history = []

    def predict_single(self, x):
        return sum(w * xi for w, xi in zip(self.weights, x)) + self.bias

    def predict(self, X):
        return [self.predict_single(x) for x in X]

    def compute_cost(self, X, y):
        predictions = self.predict(X)
        n = len(y)
        return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n

    def fit(self, X, y, epochs=1000, print_every=200):
        n = len(y)
        n_features = len(X[0])
        for epoch in range(epochs):
            predictions = self.predict(X)
            errors = [pred - actual for pred, actual in zip(predictions, y)]
            for j in range(n_features):
                grad = (2 / n) * sum(errors[i] * X[i][j] for i in range(n))
                self.weights[j] -= self.lr * grad
            grad_b = (2 / n) * sum(errors)
            self.bias -= self.lr * grad_b
            cost = self.compute_cost(X, y)
            self.cost_history.append(cost)
            if epoch % print_every == 0:
                print(f"  Epoch {epoch:4d} | Cost: {cost:.4f}")
        return self

    def r_squared(self, X, y):
        predictions = self.predict(X)
        y_mean = sum(y) / len(y)
        ss_res = sum((actual - pred) ** 2 for actual, pred in zip(y, predictions))
        ss_tot = sum((actual - y_mean) ** 2 for actual in y)
        return 1 - (ss_res / ss_tot)


random.seed(42)
N = 100
X_multi = []
y_multi = []
for _ in range(N):
    size = random.uniform(500, 3000)
    bedrooms = random.randint(1, 5)
    age = random.uniform(0, 50)
    price = 50 * size + 10000 * bedrooms - 1000 * age + 50000 + random.gauss(0, 20000)
    X_multi.append([size, bedrooms, age])
    y_multi.append(price)


def standardize(X):
    n_features = len(X[0])
    means = [sum(X[i][j] for i in range(len(X))) / len(X) for j in range(n_features)]
    stds = []
    for j in range(n_features):
        variance = sum((X[i][j] - means[j]) ** 2 for i in range(len(X))) / len(X)
        stds.append(variance ** 0.5)
    X_scaled = []
    for i in range(len(X)):
        row = [(X[i][j] - means[j]) / stds[j] if stds[j] > 0 else 0 for j in range(n_features)]
        X_scaled.append(row)
    return X_scaled, means, stds


y_mean_val = sum(y_multi) / len(y_multi)
y_std_val = (sum((yi - y_mean_val) ** 2 for yi in y_multi) / len(y_multi)) ** 0.5
y_scaled = [(yi - y_mean_val) / y_std_val for yi in y_multi]

X_scaled, x_means, x_stds = standardize(X_multi)

print("\n=== Multiple Linear Regression (3 features) ===")
print("Features: house size, bedrooms, age")
multi_model = MultipleLinearRegression(n_features=3, learning_rate=0.01)
multi_model.fit(X_scaled, y_scaled, epochs=1000, print_every=200)

print(f"\nWeights (standardized): {[round(w, 4) for w in multi_model.weights]}")
print(f"Bias (standardized): {multi_model.bias:.4f}")
print(f"R-squared: {multi_model.r_squared(X_scaled, y_scaled):.4f}")
# Out:
# === Multiple Linear Regression (3 features) ===
# Features: house size, bedrooms, age
#   Epoch    0 | Cost: 0.9582
#   Epoch  200 | Cost: 0.1195
#   Epoch  400 | Cost: 0.1193
#   Epoch  600 | Cost: 0.1193
#   Epoch  800 | Cost: 0.1193
#
# Weights (standardized): [0.7716, 0.2773, -0.2739]
# Bias (standardized): 0.0000
# R-squared: 0.8807

# %%
X = [
    [2, 70, 3],
    [3, 75, 5],
    [4, 80, 6],
    [5, 85, 7],
    [6, 90, 8],
    [7, 92, 9],
    [8, 95, 10],
    [9, 97, 10],
    [10, 98, 10],
    [11, 100, 10],
]

y = [
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    92,
    96,
    100,
]


X_test = [
    [2.5, 72, 4],
    [3.5, 78, 5],
    [4.5, 83, 6],
    [5.5, 87, 7],
    [6.5, 91, 8],
    [7.5, 94, 9],
    [8.5, 96, 10],
    [9.5, 99, 10],
]

# Expected Marks
y_test = [
    44,
    52,
    60,
    68,
    76,
    84,
    90,
    98,
]

# %%
multi_model = MultipleLinearRegression(n_features=3, learning_rate=0.01)
multi_model.fit(X, y, epochs=1000, print_every=200)
# Out:
#   Epoch    0 | Cost: 143116825.9023
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 multi_model = MultipleLinearRegression(n_features=3, learning_rate=0.01)
# ----> 2 multi_model.fit(X, y, epochs=1000, print_every=200)
#
# Cell In[1], line 32, in MultipleLinearRegression.fit(self, X, y, epochs, print_every)
#      28                 grad = (2 / n) * sum(errors[i] * X[i][j] for i in range(n))
#      29                 self.weights[j] -= self.lr * grad
#      30             grad_b = (2 / n) * sum(errors)
#      31             self.bias -= self.lr * grad_b
# ---> 32             cost = self.compute_cost(X, y)
#      33             self.cost_history.append(cost)
#      34             if epoch % print_every == 0:
#      35                 print(f"  Epoch {epoch:4d} | Cost: {cost:.4f}")
#
# Cell In[1], line 19, in MultipleLinearRegression.compute_cost(self, X, y)
#      16     def compute_cost(self, X, y):
#      17         predictions = self.predict(X)
#      18         n = len(y)
# ---> 19         return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n
#
# Cell In[1], line 19, in MultipleLinearRegression.compute_cost.<locals>.<genexpr>(.0)
# ---> 19     def compute_cost(self, X, y):
#      20         predictions = self.predict(X)
#      21         n = len(y)
#      22         return sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n
#
# OverflowError: (34, 'Result too large')
