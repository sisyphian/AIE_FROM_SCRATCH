# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X=iris["data"]
y=iris["target"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
print(f"GaussianNB accuracy: {gnb.score(X_test, y_test):.3f}")

mnb = MultinomialNB(alpha=1.0)
mnb.fit(X_train, y_train)
print(f"MultinomialNB accuracy: {mnb.score(X_test, y_test):.3f}")
# Out:
# GaussianNB accuracy: 0.911
# MultinomialNB accuracy: 0.933

# %%
# For text classification with sklearn:

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

text_clf = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("classifier", MultinomialNB(alpha=1.0)),
])

# text_clf.fit(train_texts, train_labels)
# accuracy = text_clf.score(test_texts, test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8     ("vectorizer", CountVectorizer()),
#       9     ("classifier", MultinomialNB(alpha=1.0)),
#      10 ])
#      11
# ---> 12 text_clf.fit(train_texts, train_labels)
#      13 accuracy = text_clf.score(test_texts, test_labels)
#
# NameError: name 'train_texts' is not defined
