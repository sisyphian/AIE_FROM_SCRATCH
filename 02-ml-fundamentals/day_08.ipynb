# %% [markdown]
# # Day 8: 2026-07-14## Phase(s)P2: ML Fundamentals## Lessons Covered03 Logistic Regression & Classification; 04 Decision Trees & Random Forests; 05 Support Vector Machines; 06 K-Nearest Neighbors & Distance Metrics## Est. Study Time (hrs)5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Prep-Time Model## Project Application TaskApply today's ML concept to the CartQ LightGBM prep-time prediction feature (feature engineering, evaluation, or tuning on synthetic order data).
