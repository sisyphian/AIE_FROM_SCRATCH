# %% [markdown]
# # Day 11: 2026-07-18## Phase(s)P2: ML Fundamentals | P3: Deep Learning Core## Lessons Covered17 Handling Imbalanced Data; 18 Feature Selection; 01 The Perceptron — Where It All Started; 02 Multi-Layer Networks & Forward Pass; 03 Backpropagation from Scratch## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Prep-Time Model## Project Application TaskExtend the CartQ prep-time model notebook with today's deep learning concept (e.g. a small NN baseline to compare against LightGBM).
