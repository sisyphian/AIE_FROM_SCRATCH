# %% [markdown]
# # Day 71: 2026-09-26## Phase(s)P15: Autonomous Systems## Lessons Covered07 Recursive Self-Improvement — Capability vs Alignment; 08 Bounded Self-Improvement Designs; 09 Autonomous Coding Agent Landscape (SWE-bench, CodeAct); 10 Claude Code Permission Modes and Auto Mode; 11 Browser Agents and Indirect Prompt Injection; 12 Durable Execution for Long-Running Agents## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Guardrails## Project Application TaskAdd safety guardrails, action budgets, or rollback checkpoints to the Bengali AI agent using today's autonomous-systems concept.
