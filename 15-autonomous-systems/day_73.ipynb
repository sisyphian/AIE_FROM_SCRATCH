# %% [markdown]
# # Day 73: 2026-09-28## Phase(s)P15: Autonomous Systems | P16: Multi-Agent & Swarms## Lessons Covered18 Llama Guard and Input/Output Classification; 19 Anthropic Responsible Scaling Policy v3.0; 20 OpenAI Preparedness Framework and DeepMind FSF; 21 METR Time Horizons and External Evaluation; 22 CAIS, CAISI, and Societal-Scale Risk; 01 Why Multi-Agent; 02 FIPA-ACL Heritage and Speech Acts## Est. Study Time (hrs)5.75## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/01-why-multi-agent/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/02-fipa-acl-heritage/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ Multi-Agent Ops## Project Application TaskPrototype a multi-agent pattern for CartQ (e.g. vendor-agent + customer-agent + dispatcher) using today's multi-agent concept.
