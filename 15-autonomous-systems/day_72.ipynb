# %% [markdown]
# # Day 72: 2026-09-27## Phase(s)P15: Autonomous Systems## Lessons Covered13 Action Budgets, Iteration Caps, Cost Governors; 14 Kill Switches, Circuit Breakers, Canary Tokens; 15 HITL — Propose-Then-Commit; 16 Checkpoints and Rollback; 17 Constitutional AI and Rule Overrides## Est. Study Time (hrs)5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Guardrails## Project Application TaskAdd safety guardrails, action budgets, or rollback checkpoints to the Bengali AI agent using today's autonomous-systems concept.## MilestonePHASE 15 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
