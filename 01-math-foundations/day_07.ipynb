# %% [markdown]
# # Day 7: 2026-07-13## Phase(s)P1: Math Foundations | P2: ML Fundamentals## Lessons Covered19 Complex Numbers for AI; 20 The Fourier Transform; 21 Graph Theory for ML; 22 Stochastic Processes; 01 What Is Machine Learning — Types & Taxonomy; 02 Linear Regression from Scratch## Est. Study Time (hrs)5.5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Prep-Time Model## Project Application TaskApply today's ML concept to the CartQ LightGBM prep-time prediction feature (feature engineering, evaluation, or tuning on synthetic order data).
