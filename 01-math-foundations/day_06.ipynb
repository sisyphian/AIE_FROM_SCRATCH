# %% [markdown]
# # Day 6: 2026-07-12## Phase(s)P1: Math Foundations## Lessons Covered14 Norms & Distances; 15 Statistics for ML; 16 Sampling Methods; 17 Linear Systems; 18 Convex Optimization## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectSetup## Project Application TaskReproduce today's math concept in a Jupyter notebook using a CartQ dataset (e.g. order counts, prep times) instead of toy data.## MilestonePHASE 1 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
