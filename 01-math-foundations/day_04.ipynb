# %% [markdown]
# # Day 4: 2026-07-09## Phase(s)P1: Math Foundations## Lessons Covered04 Calculus for ML — Derivatives & Gradients; 05 Chain Rule & Automatic Differentiation; 06 Probability & Distributions; 07 Bayes' Theorem & Statistical Thinking; 08 Optimization — Gradient Descent Family## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectSetup## Project Application TaskReproduce today's math concept in a Jupyter notebook using a CartQ dataset (e.g. order counts, prep times) instead of toy data.
