# %% [markdown]
# # Day 62: 2026-09-15## Phase(s)P14: Agent Engineering## Lessons Covered01 The Agent Loop; 02 ReWOO and Plan-and-Execute; 03 Reflexion and Verbal Reinforcement Learning; 04 Tree of Thoughts and LATS; 05 Self-Refine and CRITIC## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Agent Loop## Project Application TaskBuild/extend the Bengali AI agent's core loop, memory, or tool-use using today's agent engineering pattern.
