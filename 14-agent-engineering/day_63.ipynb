# %% [markdown]
# # Day 63: 2026-09-16## Phase(s)P14: Agent Engineering## Lessons Covered06 Tool Use and Function Calling; 07 Memory — Virtual Context and MemGPT; 08 Memory Blocks and Sleep-Time Compute (Letta); 09 Hybrid Memory — Vector + Graph + KV (Mem0); 10 Skill Libraries and Lifelong Learning (Voyager)## Est. Study Time (hrs)6## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Agent Loop## Project Application TaskBuild/extend the Bengali AI agent's core loop, memory, or tool-use using today's agent engineering pattern.
