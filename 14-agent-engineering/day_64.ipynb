# %% [markdown]
# # Day 64: 2026-09-17## Phase(s)P14: Agent Engineering## Lessons Covered11 Planning with HTN and Evolutionary Search; 12 Anthropic's Workflow Patterns; 13 LangGraph — Stateful Graphs and Durable Execution; 14 AutoGen v0.4 — Actor Model; 15 CrewAI — Role-Based Crews and Flows## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Agent Loop## Project Application TaskBuild/extend the Bengali AI agent's core loop, memory, or tool-use using today's agent engineering pattern.
