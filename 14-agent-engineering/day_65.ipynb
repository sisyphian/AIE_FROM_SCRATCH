# %% [markdown]
# # Day 65: 2026-09-19## Phase(s)P14: Agent Engineering## Lessons Covered16 OpenAI Agents SDK — Handoffs, Guardrails, Tracing; 17 Claude Agent SDK — Subagents and Session Store; 18 Agno and Mastra — Production Runtimes; 19 Benchmarks — SWE-bench, GAIA, AgentBench; 20 Benchmarks — WebArena and OSWorld## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Agent Loop## Project Application TaskBuild/extend the Bengali AI agent's core loop, memory, or tool-use using today's agent engineering pattern.
