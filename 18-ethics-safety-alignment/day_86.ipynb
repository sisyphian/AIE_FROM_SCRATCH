# %% [markdown]
# # Day 86: 2026-10-13## Phase(s)P18: Ethics, Safety & Alignment## Lessons Covered08 In-Context Scheming in Frontier Models; 09 Alignment Faking; 10 AI Control — Safety Despite Subversion; 11 Scalable Oversight & Weak-to-Strong Generalization; 12 Red-Teaming — PAIR & Automated Attacks## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/08-in-context-scheming-frontier-models | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/09-alignment-faking | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/10-ai-control-subversion | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/11-scalable-oversight-weak-to-strong | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/12-red-teaming-pair-automated-attacks## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Safety Eval## Project Application TaskAdd an eval-harness or red-team test case for the Bengali AI agent using today's ethics/safety/alignment concept.
