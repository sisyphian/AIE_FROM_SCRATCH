# %% [markdown]
# # Day 87: 2026-10-14## Phase(s)P18: Ethics, Safety & Alignment## Lessons Covered13 Many-Shot Jailbreaking; 14 ASCII Art & Visual Jailbreaks; 15 Indirect Prompt Injection; 16 Red-Team Tooling — Garak, Llama Guard, PyRIT; 17 WMDP & Dual-Use Capability Evaluation## Est. Study Time (hrs)5.25## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/13-many-shot-jailbreaking | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/14-ascii-art-visual-jailbreaks | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/15-indirect-prompt-injection | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/16-red-team-tooling-garak-llamaguard-pyrit | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/17-wmdp-dual-use-evaluation## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Safety Eval## Project Application TaskAdd an eval-harness or red-team test case for the Bengali AI agent using today's ethics/safety/alignment concept.
