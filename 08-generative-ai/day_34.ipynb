# %% [markdown]
# # Day 34: 2026-08-13## Phase(s)P8: Generative AI | P9: Reinforcement Learning## Lessons Covered14 Evaluation — FID, CLIP Score, Human Preference; 19 Visual Autoregressive Modeling (VAR): Next-Scale Prediction; 01 MDPs, States, Actions & Rewards; 02 Dynamic Programming; 03 Monte Carlo Methods## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/14-evaluation-fid-clip-score/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/19-visual-autoregressive-var## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Dynamic Pricing (stretch)## Project Application TaskOptional stretch: sketch how today's RL concept could drive CartQ dynamic pricing or delivery-batching decisions (design note, not full build).
