# %% [markdown]
# # Day 33: 2026-08-12## Phase(s)P8: Generative AI## Lessons Covered08 ControlNet, LoRA & Image Conditioning; 09 Inpainting, Outpainting & Image Editing; 10 Video Generation; 11 Audio Generation; 12 3D Generation; 13 Flow Matching & Rectified Flows## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/08-controlnet-lora-conditioning/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/09-inpainting-outpainting-editing/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/10-video-generation/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/11-audio-generation/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/12-3d-generation/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/13-flow-matching-rectified-flows/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Marketing Assets (stretch)## Project Application TaskOptional stretch: generate a promotional image/asset variant for a CartQ vendor listing using today's generative technique.## MilestonePHASE 8 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
