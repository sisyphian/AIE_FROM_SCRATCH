# %% [markdown]
# # Day 32: 2026-08-11## Phase(s)P8: Generative AI## Lessons Covered03 GANs — Generator vs Discriminator; 04 Conditional GANs & Pix2Pix; 05 StyleGAN; 06 Diffusion Models — DDPM from Scratch; 07 Latent Diffusion & Stable Diffusion## Est. Study Time (hrs)5.75## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/03-gans-generator-discriminator/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/04-conditional-gans-pix2pix/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/05-stylegan/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/06-diffusion-ddpm-from-scratch/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/07-latent-diffusion-stable-diffusion/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Marketing Assets (stretch)## Project Application TaskOptional stretch: generate a promotional image/asset variant for a CartQ vendor listing using today's generative technique.
