# %% [markdown]
# # Day 25: 2026-08-03## Phase(s)P5: NLP | P6: Speech & Audio## Lessons Covered29 Dialogue State Tracking; 01 Audio Fundamentals — Waveforms, Sampling, Fourier Transform; 02 Spectrograms, Mel Scale & Audio Features; 03 Audio Classification; 04 Speech Recognition (ASR); 05 Whisper — Architecture & Fine-Tuning## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/29-dialogue-state-tracking | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/06-speech-and-audio/01-audio-fundamentals | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/06-speech-and-audio/02-spectrograms-mel-features | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/06-speech-and-audio/03-audio-classification | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/06-speech-and-audio/04-speech-recognition-asr | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/06-speech-and-audio/05-whisper-architecture-finetuning## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Bangla Voice Ordering## Project Application TaskApply today's speech/audio technique directly to the CartQ Bangla voice-ordering pipeline (ASR, TTS, or streaming audio handling).
