# %% [markdown]
# # Day 24: 2026-08-02## Phase(s)P5: NLP## Lessons Covered24 Coreference Resolution; 25 Entity Linking & Disambiguation; 26 Relation Extraction & Knowledge Graph Construction; 27 LLM Evaluation — RAGAS, DeepEval, G-Eval; 28 Long-Context Evaluation — NIAH, RULER, LongBench, MRCR## Est. Study Time (hrs)5.25## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/24-coreference-resolution | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/25-entity-linking | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/26-relation-extraction-kg | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/27-llm-evaluation-frameworks | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/28-long-context-evaluation## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Search & Bangla Agent## Project Application TaskApply today's NLP technique to CartQ product search or the Bengali AI agent (tokenization, embeddings, or retrieval on Bangla/English menu text).## MilestonePHASE 5 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
