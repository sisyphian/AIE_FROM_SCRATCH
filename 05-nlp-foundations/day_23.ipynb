# %% [markdown]
# # Day 23: 2026-08-01## Phase(s)P5: NLP## Lessons Covered18 Multilingual NLP; 19 Subword Tokenization — BPE, WordPiece, Unigram, SentencePiece; 20 Structured Outputs & Constrained Decoding; 21 NLI & Textual Entailment; 22 Embedding Models Deep Dive; 23 Chunking Strategies for RAG## Est. Study Time (hrs)5.75## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/18-multilingual-nlp | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/19-subword-tokenization | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/20-structured-outputs-constrained-decoding | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/21-nli-textual-entailment | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/22-embedding-models-deep-dive | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/23-chunking-strategies-rag## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Search & Bangla Agent## Project Application TaskApply today's NLP technique to CartQ product search or the Bengali AI agent (tokenization, embeddings, or retrieval on Bangla/English menu text).
