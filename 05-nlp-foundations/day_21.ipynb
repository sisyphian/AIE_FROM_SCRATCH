# %% [markdown]
# # Day 21: 2026-07-29## Phase(s)P5: NLP## Lessons Covered08 Text Classification — CNNs & RNNs for Text; 09 Sequence-to-Sequence Models; 10 Attention Mechanism — The Breakthrough; 11 Machine Translation; 12 Text Summarization## Est. Study Time (hrs)5.75## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/08-cnns-rnns-for-text | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/09-sequence-to-sequence | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/10-attention-mechanism | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/11-machine-translation | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/05-nlp-foundations-to-advanced/12-text-summarization## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Search & Bangla Agent## Project Application TaskApply today's NLP technique to CartQ product search or the Bengali AI agent (tokenization, embeddings, or retrieval on Bangla/English menu text).
