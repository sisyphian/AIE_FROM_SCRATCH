# %% [markdown]
# # Day 15: 2026-07-22## Phase(s)P4: Computer Vision## Lessons Covered06 Object Detection — YOLO from Scratch; 07 Semantic Segmentation — U-Net; 08 Instance Segmentation — Mask R-CNN; 09 Image Generation — GANs## Est. Study Time (hrs)5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Menu Vision (stretch)## Project Application TaskOptional stretch: prototype a menu-photo OCR/classification snippet for CartQ's vendor onboarding flow using today's CV technique.
