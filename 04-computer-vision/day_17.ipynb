# %% [markdown]
# # Day 17: 2026-07-25## Phase(s)P4: Computer Vision## Lessons Covered16 Build a Complete Vision Pipeline; 17 Self-Supervised Vision — SimCLR, DINO, MAE; 18 Open-Vocabulary Vision — CLIP; 19 OCR & Document Understanding; 20 Image Retrieval & Metric Learning## Est. Study Time (hrs)5.5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Menu Vision (stretch)## Project Application TaskOptional stretch: prototype a menu-photo OCR/classification snippet for CartQ's vendor onboarding flow using today's CV technique.
