# %% [markdown]
# # Day 18: 2026-07-26## Phase(s)P4: Computer Vision## Lessons Covered21 Keypoint Detection & Pose Estimation; 22 3D Gaussian Splatting from Scratch; 23 Diffusion Transformers & Rectified Flow; 24 SAM 3 & Open-Vocabulary Segmentation; 25 Vision-Language Models (ViT-MLP-LLM)## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Menu Vision (stretch)## Project Application TaskOptional stretch: prototype a menu-photo OCR/classification snippet for CartQ's vendor onboarding flow using today's CV technique.## MilestonePHASE 4 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
