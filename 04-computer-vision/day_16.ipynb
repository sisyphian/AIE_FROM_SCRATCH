# %% [markdown]
# # Day 16: 2026-07-23## Phase(s)P4: Computer Vision## Lessons Covered10 Image Generation — Diffusion Models; 11 Stable Diffusion — Architecture & Fine-Tuning; 12 Video Understanding — Temporal Modeling; 13 3D Vision — Point Clouds, NeRFs; 14 Vision Transformers (ViT); 15 Real-Time Vision — Edge Deployment## Est. Study Time (hrs)6## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Menu Vision (stretch)## Project Application TaskOptional stretch: prototype a menu-photo OCR/classification snippet for CartQ's vendor onboarding flow using today's CV technique.
