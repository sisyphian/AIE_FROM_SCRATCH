# %% [markdown]
# # Day 14: 2026-07-21## Phase(s)P4: Computer Vision## Lessons Covered01 Image Fundamentals — Pixels, Channels, Color Spaces; 02 Convolutions from Scratch; 03 CNNs — LeNet to ResNet; 04 Image Classification; 05 Transfer Learning & Fine-Tuning## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Menu Vision (stretch)## Project Application TaskOptional stretch: prototype a menu-photo OCR/classification snippet for CartQ's vendor onboarding flow using today's CV technique.
