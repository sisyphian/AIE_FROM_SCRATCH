# %% [markdown]
# # Day 12: 2026-07-19## Phase(s)P3: Deep Learning Core## Lessons Covered04 Activation Functions — ReLU, Sigmoid, GELU & Why; 05 Loss Functions — MSE, Cross-Entropy, Contrastive; 06 Optimizers — SGD, Momentum, Adam, AdamW; 07 Regularization — Dropout, Weight Decay, BatchNorm; 08 Weight Initialization & Training Stability; 09 Learning Rate Schedules & Warmup## Est. Study Time (hrs)5.5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Prep-Time Model## Project Application TaskExtend the CartQ prep-time model notebook with today's deep learning concept (e.g. a small NN baseline to compare against LightGBM).
