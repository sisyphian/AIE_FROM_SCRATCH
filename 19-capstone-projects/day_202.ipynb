# %% [markdown]
# # Day 202: 2027-02-25## Phase(s)P19: Capstone Projects## Lessons Covered44 Cosine LR with Linear Warmup; 45 Gradient Clipping and Mixed Precision; 46 Gradient Accumulation; 47 Checkpoint Save and Resume## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/44-cosine-lr-warmup | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/45-gradient-clipping-amp | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/46-gradient-accumulation | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/47-checkpoint-save-resume## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCapstone Integration## Project Application TaskAdapt this capstone project's pattern into either CartQ or the Bengali AI agent eval harness, or keep it as a standalone portfolio repo if not directly applicable.
