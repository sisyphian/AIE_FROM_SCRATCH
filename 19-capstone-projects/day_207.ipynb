# %% [markdown]
# # Day 207: 2027-03-03## Phase(s)P19: Capstone Projects## Lessons Covered64 Chunking Strategies, Compared; 65 Hybrid Retrieval with BM25 and Dense Embeddings; 66 Cross-Encoder Reranker; 67 Query Rewriting: HyDE, Multi-Query, and Decomposition## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/64-chunking-strategies-advanced | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/65-hybrid-retrieval-bm25-dense | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/66-reranker-cross-encoder | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/19-capstone-projects/67-query-rewriting-hyde## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCapstone Integration## Project Application TaskAdapt this capstone project's pattern into either CartQ or the Bengali AI agent eval harness, or keep it as a standalone portfolio repo if not directly applicable.
