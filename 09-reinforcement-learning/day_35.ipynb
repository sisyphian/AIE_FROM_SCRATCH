# %% [markdown]
# # Day 35: 2026-08-15## Phase(s)P9: Reinforcement Learning## Lessons Covered04 Temporal Difference — Q-Learning, SARSA; 05 Deep Q-Networks (DQN); 06 Policy Gradient Methods — REINFORCE; 07 Actor-Critic — A2C, A3C## Est. Study Time (hrs)5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Dynamic Pricing (stretch)## Project Application TaskOptional stretch: sketch how today's RL concept could drive CartQ dynamic pricing or delivery-batching decisions (design note, not full build).## MilestonePHASE 9 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
