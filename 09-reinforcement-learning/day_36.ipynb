# %% [markdown]
# # Day 36: 2026-08-16## Phase(s)P9: Reinforcement Learning | P10: LLMs from Scratch## Lessons Covered08 Proximal Policy Optimization (PPO); 09 Reward Modeling & RLHF; 10 Multi-Agent RL; 11 Sim-to-Real Transfer; 12 RL for Games; 01 Tokenizers — BPE, WordPiece, SentencePiece## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/01-tokenizers## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Evaluation## Project Application TaskRelate today's from-scratch LLM concept to the evaluation/fine-tuning approach you'll use for the Bengali AI agent's eval harness.
