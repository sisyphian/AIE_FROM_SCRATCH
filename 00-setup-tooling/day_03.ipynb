# %% [markdown]
# # Day 3: 2026-07-08
#
# ## Phase(s)
# P0: Setup & Tooling | P1: Math Foundations
#
# ## Lessons Covered
# 10 Terminal & Shell; 11 Linux for AI; 12 Debugging & Profiling; 01 Linear Algebra Intuition; 02 Vectors, Matrices & Operations; 03 Matrix Transformations & Eigenvalues
#
# ## Est. Study Time (hrs)
# 6
#
# ## Resources (links)
# https://aiengineeringfromscratch.com/catalog.html
#
# ## Daily Task
# Read/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.
#
# ## Assignment
# Write a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.
#
# ## Cumulative Project
# Setup
#
# ## Project Application Task
# Reproduce today's math concept in a Jupyter notebook using a CartQ dataset (e.g. order counts, prep times) instead of toy data.

# %%
print("Kernal Is Ready")
# Out:
# Kernal Is Ready

# %%
# !echo $SHELL
# Out:
# /bin/bash

# %%
# Count how many times "loss" appears in a log
cat train.log | grep "loss" | wc -l

# Extract just the loss values from training output
grep "loss:" train.log | awk '{print $NF}' > losses.txt

# Watch a log file update in real time, filtering for errors
tail -f train.log | grep --line-buffered "ERROR"

# Sort experiments by final accuracy
grep "final_accuracy" results/*.log | sort -t= -k2 -n -r

# Redirect stdout and stderr to separate files
python train.py > output.log 2> errors.log

# Redirect both to the same file
python train.py > train_full.log 2>&1

# %%
# !nvidia-smi --query-compute-apps=pid,name,used_memory --format=csv
# Out:
# pid, process_name, used_gpu_memory [MiB]
# 19482, /usr/bin/python3, 234 MiB

# %% [markdown]
# Exercises:
#
# 1. Install tmux and open a session with three panes. In the first pane, run `htop`. In the second pane, run `watch -n1 date`. In the third pane, run a Python script. Detach and reattach to the session.
#
# 2. Add the aliases from `code/shell_aliases.sh` to your shell configuration file (`~/.zshrc` or `~/.bashrc`). Reload the configuration by running `source ~/.zshrc` or `source ~/.bashrc`.
#
# 3. Create a fake training log by running the following command in the terminal:

# %% [markdown]
# ### Day 3 ON DAY-04 Nacklog Cleatance

# %%
print("Kernal Is Ready")
# Out:
# Kernal Is Ready

# %%
def debug_print(name, tensor):
    print(f"{name}: shape={tensor.shape}, dtype={tensor.dtype}, "
          f"device={tensor.device}, "
          f"min={tensor.min().item():.4f}, max={tensor.max().item():.4f}, "
          f"mean={tensor.mean().item():.4f}, "
          f"has_nan={tensor.isnan().any().item()}")

# %%
def training_step(model, batch, criterion, optimizer):
    inputs, labels = batch
    outputs = model(inputs)
    loss = criterion(outputs, labels)

    if loss.item() > 100 or torch.isnan(loss):
        breakpoint()

    loss.backward()
    optimizer.step()

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler("training.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

logger.info("Starting training: lr=%.4f, batch_size=%d", lr, batch_size)
logger.warning("Loss spike detected: %.4f at step %d", loss.item(), step)
logger.error("NaN loss at step %d, stopping", step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1477/3953109199.py in <cell line: 0>()
#      11 logger = logging.getLogger(__name__)
#      12
# ---> 13 logger.info("Starting training: lr=%.4f, batch_size=%d", lr, batch_size)
#      14 logger.warning("Loss spike detected: %.4f at step %d", loss.item(), step)
#      15 logger.error("NaN loss at step %d, stopping", step)
#
# NameError: name 'lr' is not defined

# %%
import time

class Timer:
    def __init__(self, name=""):
        self.name = name

    def __enter__(self):
        self.start = time.perf_counter()
        return self

    def __exit__(self, *args):
        elapsed = time.perf_counter() - self.start
        print(f"[{self.name}] {elapsed:.4f}s")

with Timer("data loading"):
    batch = next(dataloader_iter)

with Timer("forward pass"):
    outputs = model(batch)

with Timer("backward pass"):
    loss.backward()
# Out:
# [data loading] 0.0000s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1477/497400189.py in <cell line: 0>()
#      14
#      15 with Timer("data loading"):
# ---> 16     batch = next(dataloader_iter)
#      17
#      18 with Timer("forward pass"):
#
# NameError: name 'dataloader_iter' is not defined

# %% [markdown]
# To profile a Python script, you can use the `cProfile` module. Here's how to use it:
#
# 1. Open a terminal or command prompt.
# 2. Run the following command to start profiling:
#
# ~~~
# python -m cProfile -o profile_output.prof your_script.py
# ~~~
