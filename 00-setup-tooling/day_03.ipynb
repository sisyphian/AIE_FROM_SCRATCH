# %% [markdown]
# # Day 3: 2026-07-08## Phase(s)P0: Setup & Tooling | P1: Math Foundations## Lessons Covered10 Terminal & Shell; 11 Linux for AI; 12 Debugging & Profiling; 01 Linear Algebra Intuition; 02 Vectors, Matrices & Operations; 03 Matrix Transformations & Eigenvalues## Est. Study Time (hrs)6## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectSetup## Project Application TaskReproduce today's math concept in a Jupyter notebook using a CartQ dataset (e.g. order counts, prep times) instead of toy data.
