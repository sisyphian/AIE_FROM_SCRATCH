# %% [markdown]
# # Day 2: 2026-07-07## Phase(s)P0: Setup & Tooling## Lessons Covered06 Python Environments; 07 Docker for AI; 08 Editor Setup; 09 Data Management## Est. Study Time (hrs)5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectSetup## Project Application TaskSet up the CartQ monorepo (FastAPI/Django + React), Docker Compose, and a GitHub repo with CI stub using today's tooling.## MilestonePHASE 0 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
