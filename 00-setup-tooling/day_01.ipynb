# %% [markdown]
# # Day 1: 2026-07-06## Phase(s)P0: Setup & Tooling## Lessons Covered01 Dev Environment; 02 Git & Collaboration; 03 GPU Setup & Cloud; 04 APIs & Keys; 05 Jupyter Notebooks## Est. Study Time (hrs)5.75## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectSetup## Project Application TaskSet up the CartQ monorepo (FastAPI/Django + React), Docker Compose, and a GitHub repo with CI stub using today's tooling.
