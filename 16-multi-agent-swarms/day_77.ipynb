# %% [markdown]
# # Day 77: 2026-10-03## Phase(s)P16: Multi-Agent & Swarms## Lessons Covered17 Generative Agents and Emergent Simulation; 18 Theory of Mind and Emergent Coordination; 19 Swarm Optimization for LLMs (PSO, ACO); 20 MARL — MADDPG, QMIX, MAPPO## Est. Study Time (hrs)5.25## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/17-generative-agents-simulation/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/18-theory-of-mind-coordination/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/19-swarm-optimization-pso-aco/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/16-multi-agent-and-swarms/20-marl-maddpg-qmix-mappo/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ Multi-Agent Ops## Project Application TaskPrototype a multi-agent pattern for CartQ (e.g. vendor-agent + customer-agent + dispatcher) using today's multi-agent concept.
