# %% [markdown]
# # Day 84: 2026-10-11## Phase(s)P17: Infrastructure & Production | P18: Ethics, Safety & Alignment## Lessons Covered25 Security — Secrets, PII Scrubbing, Audit Logs; 26 Compliance — SOC 2, HIPAA, GDPR, EU AI Act, ISO 42001; 27 FinOps for LLMs — Unit Economics and Multi-Tenant Attribution; 28 Self-Hosted Serving Selection — llama.cpp, Ollama, TGI, vLLM, SGLang; 01 Instruction-Following as Alignment Signal; 02 Reward Hacking & Goodhart's Law## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/01-instruction-following-alignment-signal | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/18-ethics-safety-alignment/02-reward-hacking-goodhart## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Safety Eval## Project Application TaskAdd an eval-harness or red-team test case for the Bengali AI agent using today's ethics/safety/alignment concept.
