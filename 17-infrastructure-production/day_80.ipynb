# %% [markdown]
# # Day 80: 2026-10-06## Phase(s)P17: Infrastructure & Production## Lessons Covered05 EAGLE-3 Speculative Decoding in Production; 06 SGLang and RadixAttention for Prefix-Heavy Workloads; 07 TensorRT-LLM on Blackwell with FP8 and NVFP4; 08 Inference Metrics — TTFT, TPOT, ITL, Goodput, P99; 09 Production Quantization — AWQ, GPTQ, GGUF, FP8, NVFP4## Est. Study Time (hrs)5.5## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ Production Deployment## Project Application TaskApply today's infra concept to deploying/monitoring CartQ or the Bengali agent in a production-like setup (observability, load testing, cost tracking).
