# %% [markdown]
# # Day 83: 2026-10-10## Phase(s)P17: Infrastructure & Production## Lessons Covered20 Shadow, Canary, and Progressive Deployment; 21 A/B Testing LLM Features — GrowthBook and Statsig; 22 Load Testing LLM APIs — k6, LLMPerf, GenAI-Perf; 23 SRE for AI — Multi-Agent Incident Response; 24 Chaos Engineering for LLM Production## Est. Study Time (hrs)5.25## Resources (links)https://aiengineeringfromscratch.com/catalog.html## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ Production Deployment## Project Application TaskApply today's infra concept to deploying/monitoring CartQ or the Bengali agent in a production-like setup (observability, load testing, cost tracking).## MilestonePHASE 17 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
