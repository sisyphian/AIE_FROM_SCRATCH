# %% [markdown]
# # Day 41: 2026-08-22## Phase(s)P10: LLMs from Scratch## Lessons Covered20 DeepSeek-V3 Architecture Walkthrough; 21 Jamba — Hybrid SSM-Transformer; 22 Async and Hogwild! Inference; 25 Speculative Decoding and EAGLE; 34 Gradient Checkpointing and Activation Recomputation## Est. Study Time (hrs)5.67## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/20-deepseek-v3-walkthrough | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/21-jamba-hybrid-ssm-transformer | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/22-async-hogwild-inference | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/25-speculative-decoding | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/34-gradient-checkpointing## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Evaluation## Project Application TaskRelate today's from-scratch LLM concept to the evaluation/fine-tuning approach you'll use for the Bengali AI agent's eval harness.## MilestonePHASE 10 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
