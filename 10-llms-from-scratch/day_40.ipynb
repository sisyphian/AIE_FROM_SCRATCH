# %% [markdown]
# # Day 40: 2026-08-20## Phase(s)P10: LLMs from Scratch## Lessons Covered15 Speculative Decoding and EAGLE-3; 16 Differential Attention (V2); 17 Native Sparse Attention (DeepSeek NSA); 18 Multi-Token Prediction (MTP); 19 DualPipe Parallelism## Est. Study Time (hrs)5.25## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/15-speculative-decoding-eagle3 | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/16-differential-attention-v2 | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/17-native-sparse-attention | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/18-multi-token-prediction | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/19-dualpipe-parallelism## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Evaluation## Project Application TaskRelate today's from-scratch LLM concept to the evaluation/fine-tuning approach you'll use for the Bengali AI agent's eval harness.
