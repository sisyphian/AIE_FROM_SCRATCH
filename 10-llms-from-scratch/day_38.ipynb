# %% [markdown]
# # Day 38: 2026-08-18## Phase(s)P10: LLMs from Scratch## Lessons Covered06 Instruction Tuning — SFT; 07 RLHF — Reward Model + PPO Training; 08 DPO — Direct Preference Optimization; 09 Constitutional AI & Self-Improvement; 10 Evaluation — Benchmarks, Evals, LM Harness## Est. Study Time (hrs)5.75## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/06-instruction-tuning-sft | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/07-rlhf | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/08-dpo | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/09-constitutional-ai-self-improvement | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/10-llms-from-scratch/10-evaluation## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Evaluation## Project Application TaskRelate today's from-scratch LLM concept to the evaluation/fine-tuning approach you'll use for the Bengali AI agent's eval harness.
