# %% [markdown]
# # Day 29: 2026-08-08## Phase(s)P7: Transformers Deep Dive## Lessons Covered03 Multi-Head Attention; 04 Positional Encoding — Sinusoidal, RoPE, ALiBi; 05 The Full Transformer — Encoder + Decoder; 06 BERT — Masked Language Modeling; 07 GPT — Causal Language Modeling## Est. Study Time (hrs)5.25## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/03-multi-head-attention | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/04-positional-encoding | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/05-full-transformer | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/06-bert-masked-language-modeling | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/07-gpt-causal-language-modeling## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Core Model## Project Application TaskDeepen the transformer internals behind the LLM you call from the Bengali AI agent; note how today's concept shows up in API behavior (context, attention, KV cache).
