# %% [markdown]
# # Day 31: 2026-08-10## Phase(s)P7: Transformers Deep Dive | P8: Generative AI## Lessons Covered14 Build a Transformer from Scratch — The Capstone; 15 Attention Variants — Sliding Window, Sparse, Differential; 16 Speculative Decoding — Draft, Verify, Repeat; 01 Generative Models — Taxonomy & History; 02 Autoencoders & VAE## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/14-build-a-transformer-capstone | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/15-attention-variants | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/16-speculative-decoding | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/01-generative-models-taxonomy-history/ | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/08-generative-ai/02-autoencoders-vae/## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Marketing Assets (stretch)## Project Application TaskOptional stretch: generate a promotional image/asset variant for a CartQ vendor listing using today's generative technique.
