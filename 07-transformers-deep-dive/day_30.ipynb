# %% [markdown]
# # Day 30: 2026-08-09## Phase(s)P7: Transformers Deep Dive## Lessons Covered08 T5, BART — Encoder-Decoder Models; 09 Vision Transformers (ViT); 10 Audio Transformers — Whisper Architecture; 11 Mixture of Experts (MoE); 12 KV Cache, Flash Attention & Inference Optimization; 13 Scaling Laws## Est. Study Time (hrs)5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/08-t5-bart-encoder-decoder | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/09-vision-transformers | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/10-audio-transformers-whisper | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/11-mixture-of-experts | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/12-kv-cache-flash-attention | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/07-transformers-deep-dive/13-scaling-laws## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectBangla AI Agent - Core Model## Project Application TaskDeepen the transformer internals behind the LLM you call from the Bengali AI agent; note how today's concept shows up in API behavior (context, attention, KV cache).## MilestonePHASE 7 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
