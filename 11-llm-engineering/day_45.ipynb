# %% [markdown]
# # Day 45: 2026-08-26## Phase(s)P11: LLM Engineering | P12: Multimodal AI## Lessons Covered15 Prompt Caching & Context Caching; 01 Vision Transformers and the Patch-Token Primitive; 02 CLIP and Contrastive Vision-Language Pretraining## Est. Study Time (hrs)6## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/15-prompt-caching | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/12-multimodal-ai/01-vision-transformer-patch-tokens | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/12-multimodal-ai/02-clip-contrastive-pretraining## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ - Multimodal Search (stretch)## Project Application TaskOptional stretch: prototype multimodal search/RAG over menu photos for CartQ using today's technique.
