# %% [markdown]
# # Day 43: 2026-08-24## Phase(s)P11: LLM Engineering## Lessons Covered06 RAG — Retrieval-Augmented Generation; 07 Advanced RAG; 08 Fine-Tuning with LoRA & QLoRA; 09 Function Calling & Tool Use## Est. Study Time (hrs)5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/06-rag | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/07-advanced-rag | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/08-fine-tuning-lora | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/09-function-calling## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ RAG Assistant + Bangla Agent## Project Application TaskBuild/extend the CartQ knowledge-base RAG assistant or the Bengali AI agent core using today's LLM engineering technique (prompting, RAG, function calling, or caching).
