# %% [markdown]
# # Day 44: 2026-08-25## Phase(s)P11: LLM Engineering## Lessons Covered10 Evaluation & Testing LLM Applications; 11 Caching, Rate Limiting & Cost Optimization; 12 Guardrails, Safety & Content Filtering; 13 Building a Production LLM Application; 14 Model Context Protocol (MCP)## Est. Study Time (hrs)5.5## Resources (links)https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/10-evaluation | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/11-caching-cost | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/12-guardrails | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/13-production-app | https://github.com/rohitg00/ai-engineering-from-scratch/tree/main/phases/11-llm-engineering/14-model-context-protocol## Daily TaskRead/watch the lesson material, then implement the from-scratch exercise in code (Python primary; TS/Rust/Julia optional per lesson). Run any provided tests before moving on.## AssignmentWrite a 5-6 bullet recap in your learning journal (what you built, one thing that was hard, one thing to revisit). Commit code + notes to your learning repo.## Cumulative ProjectCartQ RAG Assistant + Bangla Agent## Project Application TaskBuild/extend the CartQ knowledge-base RAG assistant or the Bengali AI agent core using today's LLM engineering technique (prompting, RAG, function calling, or caching).## MilestonePHASE 11 COMPLETE — checkpoint: review notes, run a small self-test/quiz, and push a phase-summary commit.
